# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:

# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Import the time library and the datetime module from the datetime library

import time
from datetime import datetime

# Create an empty list to hold the weather data.
city_data=[]

# Print the beginning of the logging.
print("Beginning Data Retrieval       ")
print("--------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 == 0 and i >=50):
        set_count +=1
        record_count=1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url +"&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record [record_count] of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = str(city_weather["weather"][0]["description"]) 
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record [record_count] of Set 1 | port hedland
# Processing Record [record_count] of Set 1 | saldanha
# Processing Record [record_count] of Set 1 | busselton
# Processing Record [record_count] of Set 1 | cape town
# Processing Record [record_count] of Set 1 | boa vista
# Processing Record [record_count] of Set 1 | kalmunai
# Processing Record [record_count] of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | prince rupert
# Processing Record [record_count] of Set 1 | forestville
# Processing Record [record_count] of Set 1 | rikitea
# Processing Record [record_count] of Set 1 | albany
# Processing Record [record_count] of Set 1 | barrow
# Processing Record [record_count] of Set 1 | turayf
# Processing Record [record_count] of Set 1 | mataura
# Processing Record [record_count] of Set 1 | punta arenas
# Processing Record [record_count] of Set 1 | kavieng
# Processing Record [record_count] of Set 1 | ararangua
# Processing Record [record_count] of Set 1 | puerto ayora
# Processing Record [record_count] of Set 1 | beringovskiy
# Processing Record [record_count] of Set 1 | isangel
# Processing Record [record_count] of Set 1 | port elizabeth
# Processing Record [record_count] of Set 1 | bredasdorp
# Processing Record [record_count] of Set 1 | hobyo
# Processing Record [record_count] of Set 1 | karasburg
# Processing Record [record_count] of Set 1 | deputatskiy
# Processing Record [record_count] of Set 1 | ushuaia
# Processing Record [record_count] of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | fort nelson
# Processing Record [record_count] of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | kupang
# Processing Record [record_count] of Set 1 | aklavik
# Processing Record [record_count] of Set 1 | vardo
# Processing Record [record_count] of Set 1 | kaitangata
# Processing Record [record_count] of Set 1 | porec
# Processing Record [record_count] of Set 1 | vaini
# Processing Record [record_count] of Set 1 | vagay
# Processing Record [record_count] of Set 1 | new norfolk
# Processing Record [record_count] of Set 1 | hilo
# Processing Record [record_count] of Set 1 | upernavik
# Processing Record [record_count] of Set 1 | qaanaaq
# Processing Record [record_count] of Set 1 | hobart
# Processing Record [record_count] of Set 1 | verkhnyaya inta
# Processing Record [record_count] of Set 1 | sobolevo
# Processing Record [record_count] of Set 1 | yulara
# Processing Record [record_count] of Set 1 | yumen
# Processing Record [record_count] of Set 1 | nouadhibou
# Processing Record [record_count] of Set 1 | amapa
# Processing Record [record_count] of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | naze
# Processing Record [record_count] of Set 1 | bluff
# Processing Record [record_count] of Set 2 | labytnangi
# Processing Record [record_count] of Set 2 | todos santos
# Processing Record [record_count] of Set 2 | cherskiy
# Processing Record [record_count] of Set 2 | nelson bay
# Processing Record [record_count] of Set 2 | ancud
# Processing Record [record_count] of Set 2 | port alfred
# Processing Record [record_count] of Set 2 | rio grande
# Processing Record [record_count] of Set 2 | grao mogol
# Processing Record [record_count] of Set 2 | rawson
# Processing Record [record_count] of Set 2 | narsaq
# Processing Record [record_count] of Set 2 | matamoros
# Processing Record [record_count] of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | torbay
# Processing Record [record_count] of Set 2 | jamestown
# Processing Record [record_count] of Set 2 | tomatlan
# Processing Record [record_count] of Set 2 | kaeo
# Processing Record [record_count] of Set 2 | atuona
# Processing Record [record_count] of Set 2 | carnarvon
# Processing Record [record_count] of Set 2 | touros
# Processing Record [record_count] of Set 2 | sao gabriel da cachoeira
# Processing Record [record_count] of Set 2 | dubbo
# Processing Record [record_count] of Set 2 | ballina
# Processing Record [record_count] of Set 2 | mahebourg
# Processing Record [record_count] of Set 2 | arica
# Processing Record [record_count] of Set 2 | jieshi
# Processing Record [record_count] of Set 2 | mar del plata
# Processing Record [record_count] of Set 2 | moindou
# Processing Record [record_count] of Set 2 | tutoia
# Processing Record [record_count] of Set 2 | kenai
# Processing Record [record_count] of Set 2 | mount gambier
# Processing Record [record_count] of Set 2 | cidreira
# Processing Record [record_count] of Set 2 | ilulissat
# Processing Record [record_count] of Set 2 | novyy urengoy
# Processing Record [record_count] of Set 2 | andenes
# Processing Record [record_count] of Set 2 | vilhena
# Processing Record [record_count] of Set 2 | kungurtug
# Processing Record [record_count] of Set 2 | korem
# Processing Record [record_count] of Set 2 | mohgaon
# Processing Record [record_count] of Set 2 | tuktoyaktuk
# Processing Record [record_count] of Set 2 | vila franca do campo
# Processing Record [record_count] of Set 2 | brooks
# Processing Record [record_count] of Set 2 | bubaque
# Processing Record [record_count] of Set 2 | najran
# Processing Record [record_count] of Set 2 | kapaa
# Processing Record [record_count] of Set 2 | hambantota
# Processing Record [record_count] of Set 2 | atambua
# Processing Record [record_count] of Set 2 | hermanus
# Processing Record [record_count] of Set 2 | khatanga
# Processing Record [record_count] of Set 2 | saskylakh
# Processing Record [record_count] of Set 2 | thompson
# Processing Record [record_count] of Set 3 | cururupu
# Processing Record [record_count] of Set 3 | alytus
# Processing Record [record_count] of Set 3 | onega
# Processing Record [record_count] of Set 3 | kodiak
# Processing Record [record_count] of Set 3 | faya
# Processing Record [record_count] of Set 3 | show low
# Processing Record [record_count] of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record [record_count] of Set 3 | cabo san lucas
# Processing Record [record_count] of Set 3 | maceio
# Processing Record [record_count] of Set 3 | codrington
# Processing Record [record_count] of Set 3 | east london
# Processing Record [record_count] of Set 3 | viedma
# Processing Record [record_count] of Set 3 | arraial do cabo
# Processing Record [record_count] of Set 3 | bambous virieux
# Processing Record [record_count] of Set 3 | sedelnikovo
# City not found. Skipping...
# Processing Record [record_count] of Set 3 | yellowknife
# Processing Record [record_count] of Set 3 | santa barbara
# Processing Record [record_count] of Set 3 | batagay-alyta
# Processing Record [record_count] of Set 3 | dudinka
# Processing Record [record_count] of Set 3 | georgetown
# Processing Record [record_count] of Set 3 | praia
# Processing Record [record_count] of Set 3 | bermeo
# Processing Record [record_count] of Set 3 | pedreiras
# Processing Record [record_count] of Set 3 | ribeira grande
# Processing Record [record_count] of Set 3 | sabya
# Processing Record [record_count] of Set 3 | nikolskoye
# Processing Record [record_count] of Set 3 | avarua
# Processing Record [record_count] of Set 3 | fuxin
# Processing Record [record_count] of Set 3 | marcona
# City not found. Skipping...
# Processing Record [record_count] of Set 3 | esperance
# Processing Record [record_count] of Set 3 | barabai
# Processing Record [record_count] of Set 3 | hithadhoo
# Processing Record [record_count] of Set 3 | labuan
# Processing Record [record_count] of Set 3 | faanui
# Processing Record [record_count] of Set 3 | saint anthony
# Processing Record [record_count] of Set 3 | kununurra
# Processing Record [record_count] of Set 3 | klaksvik
# Processing Record [record_count] of Set 3 | slave lake
# Processing Record [record_count] of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record [record_count] of Set 3 | sosnogorsk
# Processing Record [record_count] of Set 3 | kailua
# Processing Record [record_count] of Set 3 | arrifes
# Processing Record [record_count] of Set 3 | bonfim
# Processing Record [record_count] of Set 3 | airai
# Processing Record [record_count] of Set 3 | cananea
# Processing Record [record_count] of Set 3 | castro
# Processing Record [record_count] of Set 3 | betioky
# Processing Record [record_count] of Set 3 | provideniya
# Processing Record [record_count] of Set 3 | pemangkat
# Processing Record [record_count] of Set 3 | skelleftea
# Processing Record [record_count] of Set 4 | amderma
# City not found. Skipping...
# Processing Record [record_count] of Set 4 | tiksi
# Processing Record [record_count] of Set 4 | rypefjord
# Processing Record [record_count] of Set 4 | ugoofaaru
# Processing Record [record_count] of Set 4 | ponta do sol
# Processing Record [record_count] of Set 4 | necochea
# Processing Record [record_count] of Set 4 | kahului
# Processing Record [record_count] of Set 4 | machacamarca
# Processing Record [record_count] of Set 4 | tura
# Processing Record [record_count] of Set 4 | san luis
# Processing Record [record_count] of Set 4 | santa maria
# Processing Record [record_count] of Set 4 | bethel
# Processing Record [record_count] of Set 4 | saint george
# Processing Record [record_count] of Set 4 | kavaratti
# Processing Record [record_count] of Set 4 | labutta
# City not found. Skipping...
# Processing Record [record_count] of Set 4 | ardakan
# Processing Record [record_count] of Set 4 | bukama
# Processing Record [record_count] of Set 4 | buritis
# Processing Record [record_count] of Set 4 | estelle
# Processing Record [record_count] of Set 4 | uruzgan
# Processing Record [record_count] of Set 4 | unai
# Processing Record [record_count] of Set 4 | wasilla
# Processing Record [record_count] of Set 4 | saharsa
# Processing Record [record_count] of Set 4 | red bluff
# Processing Record [record_count] of Set 4 | kajiado
# Processing Record [record_count] of Set 4 | velikiy ustyug
# Processing Record [record_count] of Set 4 | victoria
# Processing Record [record_count] of Set 4 | paso de los toros
# Processing Record [record_count] of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record [record_count] of Set 4 | perambalur
# Processing Record [record_count] of Set 4 | berdigestyakh
# Processing Record [record_count] of Set 4 | hirara
# Processing Record [record_count] of Set 4 | markova
# Processing Record [record_count] of Set 4 | sitka
# Processing Record [record_count] of Set 4 | pacific grove
# Processing Record [record_count] of Set 4 | nanortalik
# Processing Record [record_count] of Set 4 | berlevag
# Processing Record [record_count] of Set 4 | srednekolymsk
# Processing Record [record_count] of Set 4 | muli
# Processing Record [record_count] of Set 4 | verkhnevilyuysk
# Processing Record [record_count] of Set 4 | belmonte
# Processing Record [record_count] of Set 4 | rehoboth
# Processing Record [record_count] of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record [record_count] of Set 4 | the valley
# Processing Record [record_count] of Set 4 | matara
# Processing Record [record_count] of Set 4 | lima
# Processing Record [record_count] of Set 4 | takoradi
# Processing Record [record_count] of Set 4 | kinango
# Processing Record [record_count] of Set 4 | hienghene
# Processing Record [record_count] of Set 4 | aporawan
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | visby
# Processing Record [record_count] of Set 5 | pangnirtung
# Processing Record [record_count] of Set 5 | lolua
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | vaitape
# Processing Record [record_count] of Set 5 | anar darreh
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | namibe
# Processing Record [record_count] of Set 5 | poplar bluff
# Processing Record [record_count] of Set 5 | ondjiva
# Processing Record [record_count] of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | port hardy
# Processing Record [record_count] of Set 5 | waingapu
# Processing Record [record_count] of Set 5 | dunstable
# Processing Record [record_count] of Set 5 | cayenne
# Processing Record [record_count] of Set 5 | salinopolis
# Processing Record [record_count] of Set 5 | bathsheba
# Processing Record [record_count] of Set 5 | meyungs
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | verbivka
# Processing Record [record_count] of Set 5 | gorontalo
# Processing Record [record_count] of Set 5 | dubreka
# Processing Record [record_count] of Set 5 | san francisco
# Processing Record [record_count] of Set 5 | hamilton
# Processing Record [record_count] of Set 5 | altamont
# Processing Record [record_count] of Set 5 | nizwa
# Processing Record [record_count] of Set 5 | samarai
# Processing Record [record_count] of Set 5 | san patricio
# Processing Record [record_count] of Set 5 | usevya
# Processing Record [record_count] of Set 5 | biskamzha
# Processing Record [record_count] of Set 5 | saint-philippe
# Processing Record [record_count] of Set 5 | chokurdakh
# Processing Record [record_count] of Set 5 | sinnamary
# Processing Record [record_count] of Set 5 | la ronge
# Processing Record [record_count] of Set 5 | honiara
# Processing Record [record_count] of Set 5 | okhotsk
# Processing Record [record_count] of Set 5 | butaritari
# Processing Record [record_count] of Set 5 | sainte-thecle
# Processing Record [record_count] of Set 5 | doha
# Processing Record [record_count] of Set 5 | eureka
# Processing Record [record_count] of Set 5 | mecca
# Processing Record [record_count] of Set 5 | lompoc
# Processing Record [record_count] of Set 5 | lagoa
# Processing Record [record_count] of Set 5 | maniitsoq
# Processing Record [record_count] of Set 5 | vanavara
# Processing Record [record_count] of Set 5 | spilimbergo
# Processing Record [record_count] of Set 5 | beloha
# Processing Record [record_count] of Set 5 | pevek
# Processing Record [record_count] of Set 5 | berbera
# Processing Record [record_count] of Set 5 | clyde river
# Processing Record [record_count] of Set 5 | zhigansk
# Processing Record [record_count] of Set 5 | turbat
# Processing Record [record_count] of Set 6 | vicuna
# Processing Record [record_count] of Set 6 | lavrentiya
# Processing Record [record_count] of Set 6 | flinders
# Processing Record [record_count] of Set 6 | olinda
# Processing Record [record_count] of Set 6 | san jose
# Processing Record [record_count] of Set 6 | grindavik
# Processing Record [record_count] of Set 6 | matrei
# City not found. Skipping...
# Processing Record [record_count] of Set 6 | inirida
# Processing Record [record_count] of Set 6 | longhua
# Processing Record [record_count] of Set 6 | anadyr
# Processing Record [record_count] of Set 6 | coahuayana
# Processing Record [record_count] of Set 6 | mayumba
# Processing Record [record_count] of Set 6 | labuhan
# Processing Record [record_count] of Set 6 | bobrovytsya
# Processing Record [record_count] of Set 6 | fortuna
# Processing Record [record_count] of Set 6 | smoky lake
# Processing Record [record_count] of Set 6 | paamiut
# Processing Record [record_count] of Set 6 | longyearbyen
# Processing Record [record_count] of Set 6 | floriano
# Processing Record [record_count] of Set 6 | charagua
# Processing Record [record_count] of Set 6 | kuche
# City not found. Skipping...
# Processing Record [record_count] of Set 6 | coihaique
# Processing Record [record_count] of Set 6 | garowe
# Processing Record [record_count] of Set 6 | iqaluit
# Processing Record [record_count] of Set 6 | ossora
# Processing Record [record_count] of Set 6 | sao filipe
# Processing Record [record_count] of Set 6 | avera
# Processing Record [record_count] of Set 6 | samarkand
# Processing Record [record_count] of Set 6 | dingle
# Processing Record [record_count] of Set 6 | pasinler
# Processing Record [record_count] of Set 6 | bridlington
# Processing Record [record_count] of Set 6 | two hills
# Processing Record [record_count] of Set 6 | lohja
# Processing Record [record_count] of Set 6 | olafsvik
# Processing Record [record_count] of Set 6 | dunmore town
# Processing Record [record_count] of Set 6 | constitucion
# Processing Record [record_count] of Set 6 | geraldton
# Processing Record [record_count] of Set 6 | longonjo
# Processing Record [record_count] of Set 6 | ekibastuz
# Processing Record [record_count] of Set 6 | tocopilla
# Processing Record [record_count] of Set 6 | sibolga
# Processing Record [record_count] of Set 6 | yekimovichi
# Processing Record [record_count] of Set 6 | totness
# Processing Record [record_count] of Set 6 | tandil
# Processing Record [record_count] of Set 6 | sao jose da coroa grande
# Processing Record [record_count] of Set 6 | yerbogachen
# Processing Record [record_count] of Set 6 | luderitz
# Processing Record [record_count] of Set 6 | samusu
# City not found. Skipping...
# Processing Record [record_count] of Set 6 | buala
# Processing Record [record_count] of Set 6 | ketchikan
# Processing Record [record_count] of Set 7 | port macquarie
# Processing Record [record_count] of Set 7 | manoel urbano
# Processing Record [record_count] of Set 7 | opuwo
# Processing Record [record_count] of Set 7 | sechura
# Processing Record [record_count] of Set 7 | bani walid
# Processing Record [record_count] of Set 7 | west wendover
# Processing Record [record_count] of Set 7 | severo-kurilsk
# Processing Record [record_count] of Set 7 | cairns
# Processing Record [record_count] of Set 7 | bengkulu
# Processing Record [record_count] of Set 7 | alofi
# Processing Record [record_count] of Set 7 | artvin
# Processing Record [record_count] of Set 7 | planaltina
# Processing Record [record_count] of Set 7 | taoudenni
# Processing Record [record_count] of Set 7 | sungaipenuh
# Processing Record [record_count] of Set 7 | yar-sale
# Processing Record [record_count] of Set 7 | belaya gora
# Processing Record [record_count] of Set 7 | dikson
# Processing Record [record_count] of Set 7 | hofn
# Processing Record [record_count] of Set 7 | san juan bautista
# Processing Record [record_count] of Set 7 | tasiilaq
# Processing Record [record_count] of Set 7 | progreso
# Processing Record [record_count] of Set 7 | port blair
# Processing Record [record_count] of Set 7 | trinidad
# Processing Record [record_count] of Set 7 | akdepe
# Processing Record [record_count] of Set 7 | utiroa
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | athens
# Processing Record [record_count] of Set 7 | elko
# Processing Record [record_count] of Set 7 | hay river
# Processing Record [record_count] of Set 7 | erenhot
# Processing Record [record_count] of Set 7 | komsomolskiy
# Processing Record [record_count] of Set 7 | bay-khaak
# Processing Record [record_count] of Set 7 | phetchabun
# Processing Record [record_count] of Set 7 | putla
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | saint-francois
# Processing Record [record_count] of Set 7 | marion
# Processing Record [record_count] of Set 7 | port lincoln
# Processing Record [record_count] of Set 7 | vysokogornyy
# Processing Record [record_count] of Set 7 | sao joao da barra
# Processing Record [record_count] of Set 7 | rio gallegos
# Processing Record [record_count] of Set 7 | boguchany
# Processing Record [record_count] of Set 7 | castlegar
# Processing Record [record_count] of Set 7 | iquique
# Processing Record [record_count] of Set 7 | san andres
# Processing Record [record_count] of Set 7 | la primavera
# Processing Record [record_count] of Set 7 | falealupo
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | sakakah
# Processing Record [record_count] of Set 7 | pucara
# Processing Record [record_count] of Set 7 | bandar-e torkaman
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | pyshchug
# Processing Record [record_count] of Set 7 | khandyga
# Processing Record [record_count] of Set 8 | zhanaozen
# Processing Record [record_count] of Set 8 | chauk
# Processing Record [record_count] of Set 8 | tromso
# Processing Record [record_count] of Set 8 | ust-maya
# Processing Record [record_count] of Set 8 | tilichiki
# Processing Record [record_count] of Set 8 | paracuru
# Processing Record [record_count] of Set 8 | wad madani
# Processing Record [record_count] of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | paita
# Processing Record [record_count] of Set 8 | nuuk
# Processing Record [record_count] of Set 8 | changji
# Processing Record [record_count] of Set 8 | jutai
# Processing Record [record_count] of Set 8 | guerrero negro
# Processing Record [record_count] of Set 8 | chuy
# Processing Record [record_count] of Set 8 | zanjan
# Processing Record [record_count] of Set 8 | emba
# Processing Record [record_count] of Set 8 | sahuaripa
# Processing Record [record_count] of Set 8 | ust-uda
# Processing Record [record_count] of Set 8 | barra do bugres
# Processing Record [record_count] of Set 8 | leua
# Processing Record [record_count] of Set 8 | znamenskoye
# Processing Record [record_count] of Set 8 | opotiki
# Processing Record [record_count] of Set 8 | port said
# Processing Record [record_count] of Set 8 | sorland
# Processing Record [record_count] of Set 8 | solnechnyy
# Processing Record [record_count] of Set 8 | new albany
# Processing Record [record_count] of Set 8 | thunder bay
# Processing Record [record_count] of Set 8 | sabang
# Processing Record [record_count] of Set 8 | motala
# Processing Record [record_count] of Set 8 | mahajanga
# Processing Record [record_count] of Set 8 | oranjemund
# Processing Record [record_count] of Set 8 | tarudant
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | luanda
# Processing Record [record_count] of Set 8 | ixtapa
# Processing Record [record_count] of Set 8 | souillac
# Processing Record [record_count] of Set 8 | hovd
# Processing Record [record_count] of Set 8 | college
# Processing Record [record_count] of Set 8 | leningradskiy
# Processing Record [record_count] of Set 8 | castanos
# Processing Record [record_count] of Set 8 | eyl
# Processing Record [record_count] of Set 8 | ostrovnoy
# Processing Record [record_count] of Set 8 | malayal
# Processing Record [record_count] of Set 8 | huntersville
# Processing Record [record_count] of Set 8 | tawkar
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | stephenville
# Processing Record [record_count] of Set 8 | katesh
# Processing Record [record_count] of Set 8 | kirakira
# Processing Record [record_count] of Set 8 | cam ranh
# Processing Record [record_count] of Set 8 | port-gentil
# Processing Record [record_count] of Set 8 | akyab
# Processing Record [record_count] of Set 9 | chor
# Processing Record [record_count] of Set 9 | quatre cocos
# Processing Record [record_count] of Set 9 | bud
# Processing Record [record_count] of Set 9 | palmer
# Processing Record [record_count] of Set 9 | sept-iles
# Processing Record [record_count] of Set 9 | alice springs
# Processing Record [record_count] of Set 9 | adrar
# Processing Record [record_count] of Set 9 | marawi
# Processing Record [record_count] of Set 9 | warri
# Processing Record [record_count] of Set 9 | tongzi
# Processing Record [record_count] of Set 9 | nazca
# Processing Record [record_count] of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | belyy yar
# Processing Record [record_count] of Set 9 | nome
# Processing Record [record_count] of Set 9 | westport
# Processing Record [record_count] of Set 9 | biak
# Processing Record [record_count] of Set 9 | wuwei
# Processing Record [record_count] of Set 9 | fairbanks
# Processing Record [record_count] of Set 9 | garden city
# Processing Record [record_count] of Set 9 | aljezur
# Processing Record [record_count] of Set 9 | guane
# Processing Record [record_count] of Set 9 | alice town
# Processing Record [record_count] of Set 9 | bereda
# Processing Record [record_count] of Set 9 | casas grandes
# Processing Record [record_count] of Set 9 | stornoway
# Processing Record [record_count] of Set 9 | gasa
# Processing Record [record_count] of Set 9 | mangai
# Processing Record [record_count] of Set 9 | kieta
# Processing Record [record_count] of Set 9 | denham springs
# Processing Record [record_count] of Set 9 | north bend
# Processing Record [record_count] of Set 9 | huarmey
# Processing Record [record_count] of Set 9 | mana
# Processing Record [record_count] of Set 9 | puerto escondido
# Processing Record [record_count] of Set 9 | ler
# Processing Record [record_count] of Set 9 | ciudad bolivar
# Processing Record [record_count] of Set 9 | tremosnice
# Processing Record [record_count] of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | khash
# Processing Record [record_count] of Set 9 | koindu
# Processing Record [record_count] of Set 9 | sistranda
# Processing Record [record_count] of Set 9 | shizunai
# Processing Record [record_count] of Set 9 | nabire
# Processing Record [record_count] of Set 9 | hasaki
# Processing Record [record_count] of Set 9 | san cristobal
# Processing Record [record_count] of Set 9 | ayan
# Processing Record [record_count] of Set 9 | enshi
# Processing Record [record_count] of Set 9 | arlit
# Processing Record [record_count] of Set 9 | esso
# Processing Record [record_count] of Set 9 | camana
# Processing Record [record_count] of Set 9 | saint-pierre
# Processing Record [record_count] of Set 10 | los llanos de aridane
# Processing Record [record_count] of Set 10 | nagai
# Processing Record [record_count] of Set 10 | kruisfontein
# Processing Record [record_count] of Set 10 | kutum
# Processing Record [record_count] of Set 10 | lebu
# Processing Record [record_count] of Set 10 | letterkenny
# Processing Record [record_count] of Set 10 | saint-paul
# Processing Record [record_count] of Set 10 | xam nua
# Processing Record [record_count] of Set 10 | whitehorse
# Processing Record [record_count] of Set 10 | shingu
# Processing Record [record_count] of Set 10 | sedalia
# Processing Record [record_count] of Set 10 | maldonado
# Processing Record [record_count] of Set 10 | chagda
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | lidkoping
# Processing Record [record_count] of Set 10 | dharur
# Processing Record [record_count] of Set 10 | vao
# Processing Record [record_count] of Set 10 | araouane
# Processing Record [record_count] of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | gannan
# Processing Record [record_count] of Set 10 | norman wells
# Processing Record [record_count] of Set 10 | zyryanka
# Processing Record [record_count] of Set 10 | ulaanbaatar
# Processing Record [record_count] of Set 10 | cabra
# Processing Record [record_count] of Set 10 | yeppoon
# Processing Record [record_count] of Set 10 | qafsah
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | dicabisagan
# Processing Record [record_count] of Set 10 | saint-andre-les-vergers
# Processing Record [record_count] of Set 10 | cockburn town
# Processing Record [record_count] of Set 10 | loveland
# Processing Record [record_count] of Set 10 | salvador
# Processing Record [record_count] of Set 10 | menongue
# Processing Record [record_count] of Set 10 | borazjan
# Processing Record [record_count] of Set 10 | road town
# Processing Record [record_count] of Set 10 | jaciara
# Processing Record [record_count] of Set 10 | nagamangala
# Processing Record [record_count] of Set 10 | senneterre
# Processing Record [record_count] of Set 10 | mizdah
# Processing Record [record_count] of Set 10 | yoichi
# Processing Record [record_count] of Set 10 | sorvag
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | tual
# Processing Record [record_count] of Set 10 | finote selam
# Processing Record [record_count] of Set 10 | ushtobe
# Processing Record [record_count] of Set 10 | owando
# Processing Record [record_count] of Set 10 | kimi
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | baglan
# Processing Record [record_count] of Set 10 | santa rosa de osos
# Processing Record [record_count] of Set 10 | husavik
# Processing Record [record_count] of Set 10 | bucerias
# Processing Record [record_count] of Set 10 | bastrop
# Processing Record [record_count] of Set 10 | oran
# Processing Record [record_count] of Set 11 | tyazhinskiy
# Processing Record [record_count] of Set 11 | hailar
# Processing Record [record_count] of Set 11 | maua
# Processing Record [record_count] of Set 11 | palmas
# Processing Record [record_count] of Set 11 | port augusta
# Processing Record [record_count] of Set 11 | bolivar
# Processing Record [record_count] of Set 11 | pierre
# Processing Record [record_count] of Set 11 | hattiesburg
# Processing Record [record_count] of Set 11 | swift current
# Processing Record [record_count] of Set 11 | ewa beach
# Processing Record [record_count] of Set 11 | wanaka
# Processing Record [record_count] of Set 11 | tahlequah
# Processing Record [record_count] of Set 11 | san cosme y damian
# Processing Record [record_count] of Set 11 | bluefield
# Processing Record [record_count] of Set 11 | mehamn
# Processing Record [record_count] of Set 11 | itoman
# Processing Record [record_count] of Set 11 | vila velha
# Processing Record [record_count] of Set 11 | miri
# Processing Record [record_count] of Set 11 | houma
# Processing Record [record_count] of Set 11 | koumac
# Processing Record [record_count] of Set 11 | minas novas
# Processing Record [record_count] of Set 11 | klooga
# Processing Record [record_count] of Set 11 | rupert
# Processing Record [record_count] of Set 11 | barbar
# City not found. Skipping...
# Processing Record [record_count] of Set 11 | yantzaza
# Processing Record [record_count] of Set 11 | lorengau
# Processing Record [record_count] of Set 11 | iquitos
# Processing Record [record_count] of Set 11 | campeche
# Processing Record [record_count] of Set 11 | sidrolandia
# Processing Record [record_count] of Set 11 | karratha
# Processing Record [record_count] of Set 11 | port shepstone
# Processing Record [record_count] of Set 11 | demidov
# Processing Record [record_count] of Set 11 | orbetello
# Processing Record [record_count] of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record [record_count] of Set 11 | sterling
# Processing Record [record_count] of Set 11 | umba
# Processing Record [record_count] of Set 11 | casa nova
# Processing Record [record_count] of Set 11 | megion
# Processing Record [record_count] of Set 11 | praia da vitoria
# Processing Record [record_count] of Set 11 | hervey bay
# Processing Record [record_count] of Set 11 | longlac
# City not found. Skipping...
# Processing Record [record_count] of Set 11 | lardos
# Processing Record [record_count] of Set 11 | ciechanow
# Processing Record [record_count] of Set 11 | creston
# Processing Record [record_count] of Set 11 | pingliang
# Processing Record [record_count] of Set 11 | barcelos
# Processing Record [record_count] of Set 11 | namatanai
# Processing Record [record_count] of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record [record_count] of Set 11 | hailun
# Processing Record [record_count] of Set 11 | tomter
# Processing Record [record_count] of Set 12 | acapulco
# Processing Record [record_count] of Set 12 | lensk
# Processing Record [record_count] of Set 12 | shimoda
# Processing Record [record_count] of Set 12 | grand-santi
# Processing Record [record_count] of Set 12 | the pas
# Processing Record [record_count] of Set 12 | kastamonu
# Processing Record [record_count] of Set 12 | tiarei
# Processing Record [record_count] of Set 12 | camocim
# Processing Record [record_count] of Set 12 | beaverlodge
# Processing Record [record_count] of Set 12 | edmonton
# Processing Record [record_count] of Set 12 | ituni
# City not found. Skipping...
# Processing Record [record_count] of Set 12 | lebowakgomo
# Processing Record [record_count] of Set 12 | garissa
# Processing Record [record_count] of Set 12 | fukue
# Processing Record [record_count] of Set 12 | margate
# Processing Record [record_count] of Set 12 | talnakh
# Processing Record [record_count] of Set 12 | timra
# Processing Record [record_count] of Set 12 | shubarshi
# Processing Record [record_count] of Set 12 | tautira
# Processing Record [record_count] of Set 12 | south lake tahoe
# Processing Record [record_count] of Set 12 | oyem
# Processing Record [record_count] of Set 12 | meulaboh
# Processing Record [record_count] of Set 12 | west odessa
# Processing Record [record_count] of Set 12 | leopold
# Processing Record [record_count] of Set 12 | yairipok
# Processing Record [record_count] of Set 12 | tiznit
# Processing Record [record_count] of Set 12 | manzhouli
# Processing Record [record_count] of Set 12 | goure
# Processing Record [record_count] of Set 12 | sakaiminato
# Processing Record [record_count] of Set 12 | general pico
# Processing Record [record_count] of Set 12 | grand-lahou
# Processing Record [record_count] of Set 12 | bafoulabe
# Processing Record [record_count] of Set 12 | dharapuram
# Processing Record [record_count] of Set 12 | tornio
# Processing Record [record_count] of Set 12 | tabukiniberu
# City not found. Skipping...
# Processing Record [record_count] of Set 12 | khani
# Processing Record [record_count] of Set 12 | saleaula
# City not found. Skipping...
# Processing Record [record_count] of Set 12 | comodoro rivadavia
# Processing Record [record_count] of Set 12 | ahipara
# Processing Record [record_count] of Set 12 | venado tuerto
# Processing Record [record_count] of Set 12 | sikasso
# Processing Record [record_count] of Set 12 | zimandu nou
# Processing Record [record_count] of Set 12 | odienne
# Processing Record [record_count] of Set 12 | karoi
# Processing Record [record_count] of Set 12 | katsuura
# Processing Record [record_count] of Set 12 | invermere
# Processing Record [record_count] of Set 12 | surgut
# Processing Record [record_count] of Set 12 | acarau
# Processing Record [record_count] of Set 12 | funadhoo
# Processing Record [record_count] of Set 12 | nikolayevka
# Processing Record [record_count] of Set 13 | nha trang
# Processing Record [record_count] of Set 13 | agdam
# Processing Record [record_count] of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record [record_count] of Set 13 | tacuarembo
# Processing Record [record_count] of Set 13 | camopi
# Processing Record [record_count] of Set 13 | qaqortoq
# Processing Record [record_count] of Set 13 | mairwa
# Processing Record [record_count] of Set 13 | usak
# Processing Record [record_count] of Set 13 | marzuq
# Processing Record [record_count] of Set 13 | unye
# City not found. Skipping...
# Processing Record [record_count] of Set 13 | portland
# Processing Record [record_count] of Set 13 | yomitan
# City not found. Skipping...
# Processing Record [record_count] of Set 13 | atbasar
# Processing Record [record_count] of Set 13 | mayo
# Processing Record [record_count] of Set 13 | teguise
# Processing Record [record_count] of Set 13 | hokitika
# Processing Record [record_count] of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record [record_count] of Set 13 | tuatapere
# Processing Record [record_count] of Set 13 | wukari
# Processing Record [record_count] of Set 13 | kita
# Processing Record [record_count] of Set 13 | falmouth
# Processing Record [record_count] of Set 13 | north platte
# Processing Record [record_count] of Set 13 | amnat charoen
# Processing Record [record_count] of Set 13 | karpogory
# Processing Record [record_count] of Set 13 | plettenberg bay
# Processing Record [record_count] of Set 13 | taburi
# City not found. Skipping...
# Processing Record [record_count] of Set 13 | kalisz
# Processing Record [record_count] of Set 13 | sao joao do piaui
# Processing Record [record_count] of Set 13 | luzon
# Processing Record [record_count] of Set 13 | havre-saint-pierre
# Processing Record [record_count] of Set 13 | vostok
# Processing Record [record_count] of Set 13 | bronzani majdan
# Processing Record [record_count] of Set 13 | talcahuano
# Processing Record [record_count] of Set 13 | sinegorye
# Processing Record [record_count] of Set 13 | manado
# Processing Record [record_count] of Set 13 | sagaing
# Processing Record [record_count] of Set 13 | sovetskiy
# Processing Record [record_count] of Set 13 | follebu
# Processing Record [record_count] of Set 13 | macau
# Processing Record [record_count] of Set 13 | escanaba
# Processing Record [record_count] of Set 13 | padang
# Processing Record [record_count] of Set 13 | portales
# Processing Record [record_count] of Set 13 | linxia
# Processing Record [record_count] of Set 13 | xining
# Processing Record [record_count] of Set 13 | saint-georges
# Processing Record [record_count] of Set 13 | caluquembe
# Processing Record [record_count] of Set 13 | ocampo
# Processing Record [record_count] of Set 13 | urumqi
# Processing Record [record_count] of Set 13 | limon
# Processing Record [record_count] of Set 13 | sumter
# Processing Record [record_count] of Set 14 | crab hill
# City not found. Skipping...
# Processing Record [record_count] of Set 14 | ndioum
# Processing Record [record_count] of Set 14 | turukhansk
# Processing Record [record_count] of Set 14 | morgan city
# Processing Record [record_count] of Set 14 | zabid
# Processing Record [record_count] of Set 14 | salalah
# Processing Record [record_count] of Set 14 | rio cuarto
# Processing Record [record_count] of Set 14 | balabac
# Processing Record [record_count] of Set 14 | launceston
# Processing Record [record_count] of Set 14 | plouzane
# Processing Record [record_count] of Set 14 | valladolid
# Processing Record [record_count] of Set 14 | kachug
# Processing Record [record_count] of Set 14 | kumano
# Processing Record [record_count] of Set 14 | ternate
# Processing Record [record_count] of Set 14 | sarangani
# Processing Record [record_count] of Set 14 | navoloki
# Processing Record [record_count] of Set 14 | sao raimundo nonato
# Processing Record [record_count] of Set 14 | san pedro
# Processing Record [record_count] of Set 14 | tocuila
# Processing Record [record_count] of Set 14 | dunedin
# Processing Record [record_count] of Set 14 | praya
# Processing Record [record_count] of Set 14 | juiz de fora
# Processing Record [record_count] of Set 14 | vestbygda
# City not found. Skipping...
# Processing Record [record_count] of Set 14 | caranavi
# Processing Record [record_count] of Set 14 | grand gaube
# Processing Record [record_count] of Set 14 | vrangel
# Processing Record [record_count] of Set 14 | rocha
# Processing Record [record_count] of Set 14 | lata
# Processing Record [record_count] of Set 14 | sassandra
# Processing Record [record_count] of Set 14 | podbelsk
# City not found. Skipping...
# Processing Record [record_count] of Set 14 | hun
# Processing Record [record_count] of Set 14 | inverell
# Processing Record [record_count] of Set 14 | salaga
# Processing Record [record_count] of Set 14 | noumea
# Processing Record [record_count] of Set 14 | arman
# Processing Record [record_count] of Set 14 | huambo
# Processing Record [record_count] of Set 14 | ust-kuyga
# Processing Record [record_count] of Set 14 | bargal
# City not found. Skipping...
# Processing Record [record_count] of Set 14 | livingston
# Processing Record [record_count] of Set 14 | taltal
# Processing Record [record_count] of Set 14 | tena
# Processing Record [record_count] of Set 14 | ust-nera
# Processing Record [record_count] of Set 14 | namwala
# Processing Record [record_count] of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record [record_count] of Set 14 | galle
# Processing Record [record_count] of Set 14 | masvingo
# Processing Record [record_count] of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record [record_count] of Set 14 | songjianghe
# Processing Record [record_count] of Set 14 | vanimo
# Processing Record [record_count] of Set 14 | sosua
# Processing Record [record_count] of Set 15 | muzhi
# Processing Record [record_count] of Set 15 | chapais
# Processing Record [record_count] of Set 15 | chicama
# Processing Record [record_count] of Set 15 | makakilo city
# Processing Record [record_count] of Set 15 | shchigry
# Processing Record [record_count] of Set 15 | wahran
# City not found. Skipping...
# Processing Record [record_count] of Set 15 | laguna
# Processing Record [record_count] of Set 15 | khomeyn
# Processing Record [record_count] of Set 15 | champerico
# Processing Record [record_count] of Set 15 | maraba
# Processing Record [record_count] of Set 15 | pafos
# Processing Record [record_count] of Set 15 | bonavista
# Processing Record [record_count] of Set 15 | san rafael
# Processing Record [record_count] of Set 15 | verkh-usugli
# Processing Record [record_count] of Set 15 | kamenka
# Processing Record [record_count] of Set 15 | mabaruma
# Processing Record [record_count] of Set 15 | ierissos
# Processing Record [record_count] of Set 15 | japura
# Processing Record [record_count] of Set 15 | zyryanovsk
# Processing Record [record_count] of Set 15 | aleksandrovsk-sakhalinskiy
# Processing Record [record_count] of Set 15 | abu zabad
# Processing Record [record_count] of Set 15 | ukiah
# Processing Record [record_count] of Set 15 | vila
# Processing Record [record_count] of Set 15 | xadani
# City not found. Skipping...
# Processing Record [record_count] of Set 15 | serra
# Processing Record [record_count] of Set 15 | mindif
# Processing Record [record_count] of Set 15 | pasni
# Processing Record [record_count] of Set 15 | santa cruz del sur
# Processing Record [record_count] of Set 15 | takapau
# Processing Record [record_count] of Set 15 | manokwari
# Processing Record [record_count] of Set 15 | bocaiuva
# Processing Record [record_count] of Set 15 | vestmanna
# Processing Record [record_count] of Set 15 | fergus falls
# Processing Record [record_count] of Set 15 | yushu
# Processing Record [record_count] of Set 15 | thiruvananthapuram
# Processing Record [record_count] of Set 15 | swellendam
# Processing Record [record_count] of Set 15 | ortakoy
# Processing Record [record_count] of Set 15 | leh
# Processing Record [record_count] of Set 15 | gornopravdinsk
# Processing Record [record_count] of Set 15 | ostersund
# Processing Record [record_count] of Set 15 | kyra
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Port Hedland -20.3167  118.5667     59.05        67           0
# 1       Saldanha -33.0117   17.9442     68.05        81           0
# 2      Busselton -33.6500  115.3333     53.19        92         100
# 3      Cape Town -33.9258   18.4232     64.11        79           0
# 4      Boa Vista   2.8197  -60.6733     87.78        66          20
# 5       Kalmunai   7.4167   81.8167     81.12        84         100
# 6  Prince Rupert  54.3161 -130.3201     53.29        96         100
# 7    Forestville  38.8451  -76.8750     81.05        84          75
# 8        Rikitea -23.1203 -134.9692     73.62        78         100
# 9         Albany  42.6001  -73.9662     83.43        64          43
#
#    Wind Speed Country                 Date Current Description
# 0        6.91      AU  2022-07-17 14:35:16           clear sky
# 1       10.02      ZA  2022-07-17 14:35:17           clear sky
# 2       14.72      AU  2022-07-17 14:35:17          light rain
# 3       14.97      ZA  2022-07-17 14:34:28           clear sky
# 4        9.22      BR  2022-07-17 14:35:17          few clouds
# 5        7.87      LK  2022-07-17 14:35:18     overcast clouds
# 6        3.44      CA  2022-07-17 14:33:00     overcast clouds
# 7        3.44      US  2022-07-17 14:35:18       broken clouds
# 8       16.35      PF  2022-07-17 14:33:22          light rain
# 9        2.01      US  2022-07-17 14:31:35    scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
new_city_df = city_data_df[new_column_order]
new_city_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Hedland      AU -20.3167  118.5667     59.05        67           0
# 1      Saldanha      ZA -33.0117   17.9442     68.05        81           0
# 2     Busselton      AU -33.6500  115.3333     53.19        92         100
# 3     Cape Town      ZA -33.9258   18.4232     64.11        79           0
# 4     Boa Vista      BR   2.8197  -60.6733     87.78        66          20
#
#    Wind Speed Current Description
# 0        6.91           clear sky
# 1       10.02           clear sky
# 2       14.72          light rain
# 3       14.97           clear sky
# 4        9.22          few clouds

# %%
# Export the DataFrame into a CSV
city_data_df.to_csv('../Weather_Database/WeatherPy_database.csv')
