# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 626

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library

import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data=[]

# Print the beginning of the logging.
print("Beginning Data Retrieval       ")
print("--------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 == 0 and i >=50):
        set_count +=1
        record_count=1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url +"&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record [record_count] of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record [record_count] of Set 1 | busselton
# Processing Record [record_count] of Set 1 | tuktoyaktuk
# Processing Record [record_count] of Set 1 | barrow
# Processing Record [record_count] of Set 1 | bethel
# Processing Record [record_count] of Set 1 | avera
# Processing Record [record_count] of Set 1 | arraial do cabo
# Processing Record [record_count] of Set 1 | salalah
# Processing Record [record_count] of Set 1 | buala
# Processing Record [record_count] of Set 1 | sao joao da barra
# Processing Record [record_count] of Set 1 | skagastrond
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | hauterive
# Processing Record [record_count] of Set 1 | urumqi
# Processing Record [record_count] of Set 1 | kahului
# Processing Record [record_count] of Set 1 | rikitea
# Processing Record [record_count] of Set 1 | riyadh
# Processing Record [record_count] of Set 1 | atuona
# Processing Record [record_count] of Set 1 | parabel
# Processing Record [record_count] of Set 1 | lata
# Processing Record [record_count] of Set 1 | qaanaaq
# Processing Record [record_count] of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | narsaq
# Processing Record [record_count] of Set 1 | grindavik
# Processing Record [record_count] of Set 1 | lebu
# Processing Record [record_count] of Set 1 | tiksi
# Processing Record [record_count] of Set 1 | punta arenas
# Processing Record [record_count] of Set 1 | brokopondo
# Processing Record [record_count] of Set 1 | tefe
# Processing Record [record_count] of Set 1 | kichera
# Processing Record [record_count] of Set 1 | turayf
# Processing Record [record_count] of Set 1 | hermanus
# Processing Record [record_count] of Set 1 | amderma
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | olafsvik
# Processing Record [record_count] of Set 1 | mananjary
# Processing Record [record_count] of Set 1 | kodiak
# Processing Record [record_count] of Set 1 | cidreira
# Processing Record [record_count] of Set 1 | vaini
# Processing Record [record_count] of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | cherskiy
# Processing Record [record_count] of Set 1 | toliary
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | mataura
# Processing Record [record_count] of Set 1 | hilo
# Processing Record [record_count] of Set 1 | metro
# Processing Record [record_count] of Set 1 | hithadhoo
# Processing Record [record_count] of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | bargal
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | cubuk
# Processing Record [record_count] of Set 1 | westport
# Processing Record [record_count] of Set 1 | georgetown
# Processing Record [record_count] of Set 1 | lorengau
# Processing Record [record_count] of Set 1 | tabou
# Processing Record [record_count] of Set 2 | albany
# Processing Record [record_count] of Set 2 | ust-tsilma
# Processing Record [record_count] of Set 2 | kupang
# Processing Record [record_count] of Set 2 | avarua
# Processing Record [record_count] of Set 2 | chumikan
# Processing Record [record_count] of Set 2 | shingu
# Processing Record [record_count] of Set 2 | henties bay
# Processing Record [record_count] of Set 2 | halalo
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | parry sound
# Processing Record [record_count] of Set 2 | ushuaia
# Processing Record [record_count] of Set 2 | severo-kurilsk
# Processing Record [record_count] of Set 2 | pangnirtung
# Processing Record [record_count] of Set 2 | karpathos
# Processing Record [record_count] of Set 2 | jibuti
# Processing Record [record_count] of Set 2 | liverpool
# Processing Record [record_count] of Set 2 | port alfred
# Processing Record [record_count] of Set 2 | mahebourg
# Processing Record [record_count] of Set 2 | maniitsoq
# Processing Record [record_count] of Set 2 | bluff
# Processing Record [record_count] of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | camacha
# Processing Record [record_count] of Set 2 | ovalle
# Processing Record [record_count] of Set 2 | lagoa
# Processing Record [record_count] of Set 2 | yar-sale
# Processing Record [record_count] of Set 2 | ilulissat
# Processing Record [record_count] of Set 2 | nikolskoye
# Processing Record [record_count] of Set 2 | norman wells
# Processing Record [record_count] of Set 2 | carnarvon
# Processing Record [record_count] of Set 2 | rawson
# Processing Record [record_count] of Set 2 | kaitangata
# Processing Record [record_count] of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | alegrete
# Processing Record [record_count] of Set 2 | kruisfontein
# Processing Record [record_count] of Set 2 | ribeira grande
# Processing Record [record_count] of Set 2 | bombay
# Processing Record [record_count] of Set 2 | alihe
# Processing Record [record_count] of Set 2 | cordoba
# Processing Record [record_count] of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | chokurdakh
# Processing Record [record_count] of Set 2 | namatanai
# Processing Record [record_count] of Set 2 | sorong
# Processing Record [record_count] of Set 2 | sao filipe
# Processing Record [record_count] of Set 2 | xuanhua
# Processing Record [record_count] of Set 2 | sechura
# Processing Record [record_count] of Set 2 | shinpokh
# Processing Record [record_count] of Set 2 | cam pha
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | boa vista
# Processing Record [record_count] of Set 2 | leningradskiy
# Processing Record [record_count] of Set 2 | ahipara
# Processing Record [record_count] of Set 2 | saint-augustin
# Processing Record [record_count] of Set 3 | ancud
# Processing Record [record_count] of Set 3 | khatanga
# Processing Record [record_count] of Set 3 | ust-omchug
# Processing Record [record_count] of Set 3 | provideniya
# Processing Record [record_count] of Set 3 | harper
# Processing Record [record_count] of Set 3 | souillac
# Processing Record [record_count] of Set 3 | fortuna
# Processing Record [record_count] of Set 3 | puerto del rosario
# Processing Record [record_count] of Set 3 | tomatlan
# Processing Record [record_count] of Set 3 | puerto ayora
# Processing Record [record_count] of Set 3 | pevek
# Processing Record [record_count] of Set 3 | cabo san lucas
# Processing Record [record_count] of Set 3 | hobyo
# Processing Record [record_count] of Set 3 | upernavik
# Processing Record [record_count] of Set 3 | conceicao das alagoas
# Processing Record [record_count] of Set 3 | bonthe
# Processing Record [record_count] of Set 3 | san patricio
# Processing Record [record_count] of Set 3 | yellowknife
# Processing Record [record_count] of Set 3 | bambous virieux
# Processing Record [record_count] of Set 3 | torbay
# Processing Record [record_count] of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record [record_count] of Set 3 | uvalde
# Processing Record [record_count] of Set 3 | cape town
# Processing Record [record_count] of Set 3 | esperance
# Processing Record [record_count] of Set 3 | shahreza
# Processing Record [record_count] of Set 3 | bengkulu
# Processing Record [record_count] of Set 3 | bredasdorp
# Processing Record [record_count] of Set 3 | kapaa
# Processing Record [record_count] of Set 3 | dolinsk
# Processing Record [record_count] of Set 3 | dingle
# Processing Record [record_count] of Set 3 | ulaanbaatar
# Processing Record [record_count] of Set 3 | nabire
# Processing Record [record_count] of Set 3 | vao
# Processing Record [record_count] of Set 3 | kijang
# Processing Record [record_count] of Set 3 | poum
# Processing Record [record_count] of Set 3 | geraldton
# Processing Record [record_count] of Set 3 | northam
# Processing Record [record_count] of Set 3 | karratha
# Processing Record [record_count] of Set 3 | manokwari
# Processing Record [record_count] of Set 3 | plettenberg bay
# Processing Record [record_count] of Set 3 | chivay
# Processing Record [record_count] of Set 3 | hobart
# Processing Record [record_count] of Set 3 | kangaatsiaq
# Processing Record [record_count] of Set 3 | paracuru
# Processing Record [record_count] of Set 3 | chuy
# Processing Record [record_count] of Set 3 | iqaluit
# Processing Record [record_count] of Set 3 | rolante
# Processing Record [record_count] of Set 3 | buraydah
# Processing Record [record_count] of Set 3 | los andes
# Processing Record [record_count] of Set 3 | kushmurun
# Processing Record [record_count] of Set 4 | karakol
# Processing Record [record_count] of Set 4 | vardo
# Processing Record [record_count] of Set 4 | saldanha
# Processing Record [record_count] of Set 4 | daru
# Processing Record [record_count] of Set 4 | otyniya
# Processing Record [record_count] of Set 4 | tual
# Processing Record [record_count] of Set 4 | sistranda
# Processing Record [record_count] of Set 4 | nueva rosita
# Processing Record [record_count] of Set 4 | ozernovskiy
# Processing Record [record_count] of Set 4 | libertador general san martin
# Processing Record [record_count] of Set 4 | new norfolk
# Processing Record [record_count] of Set 4 | tshikapa
# Processing Record [record_count] of Set 4 | alta floresta
# Processing Record [record_count] of Set 4 | ponta delgada
# Processing Record [record_count] of Set 4 | mildura
# Processing Record [record_count] of Set 4 | saint george
# Processing Record [record_count] of Set 4 | petukhovo
# Processing Record [record_count] of Set 4 | hervey bay
# Processing Record [record_count] of Set 4 | beringovskiy
# Processing Record [record_count] of Set 4 | fjerritslev
# Processing Record [record_count] of Set 4 | paradwip
# City not found. Skipping...
# Processing Record [record_count] of Set 4 | mangrol
# Processing Record [record_count] of Set 4 | port lincoln
# Processing Record [record_count] of Set 4 | praia da vitoria
# Processing Record [record_count] of Set 4 | mitsamiouli
# Processing Record [record_count] of Set 4 | katsuura
# Processing Record [record_count] of Set 4 | thompson
# Processing Record [record_count] of Set 4 | klaksvik
# Processing Record [record_count] of Set 4 | flinders
# Processing Record [record_count] of Set 4 | khomeynishahr
# City not found. Skipping...
# Processing Record [record_count] of Set 4 | severodvinsk
# Processing Record [record_count] of Set 4 | hebertville
# City not found. Skipping...
# Processing Record [record_count] of Set 4 | luderitz
# Processing Record [record_count] of Set 4 | souris
# Processing Record [record_count] of Set 4 | xinzhou
# Processing Record [record_count] of Set 4 | saskylakh
# Processing Record [record_count] of Set 4 | mehamn
# Processing Record [record_count] of Set 4 | puri
# Processing Record [record_count] of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record [record_count] of Set 4 | mbigou
# Processing Record [record_count] of Set 4 | kavaratti
# Processing Record [record_count] of Set 4 | saint-joseph
# Processing Record [record_count] of Set 4 | chicama
# Processing Record [record_count] of Set 4 | kenai
# Processing Record [record_count] of Set 4 | fairbanks
# Processing Record [record_count] of Set 4 | bonavista
# Processing Record [record_count] of Set 4 | hofn
# Processing Record [record_count] of Set 4 | tambura
# Processing Record [record_count] of Set 4 | butaritari
# Processing Record [record_count] of Set 4 | victoria
# Processing Record [record_count] of Set 5 | bagado
# Processing Record [record_count] of Set 5 | datong
# Processing Record [record_count] of Set 5 | manadhoo
# Processing Record [record_count] of Set 5 | laguna
# Processing Record [record_count] of Set 5 | itarema
# Processing Record [record_count] of Set 5 | acucena
# Processing Record [record_count] of Set 5 | chadiza
# Processing Record [record_count] of Set 5 | pisco
# Processing Record [record_count] of Set 5 | longyearbyen
# Processing Record [record_count] of Set 5 | mar del plata
# Processing Record [record_count] of Set 5 | vigrestad
# Processing Record [record_count] of Set 5 | yerbogachen
# Processing Record [record_count] of Set 5 | tasiilaq
# Processing Record [record_count] of Set 5 | fethiye
# Processing Record [record_count] of Set 5 | aflu
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | moron
# Processing Record [record_count] of Set 5 | kerki
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | tortoli
# Processing Record [record_count] of Set 5 | lavrentiya
# Processing Record [record_count] of Set 5 | port elizabeth
# Processing Record [record_count] of Set 5 | aktau
# Processing Record [record_count] of Set 5 | haines junction
# Processing Record [record_count] of Set 5 | galle
# Processing Record [record_count] of Set 5 | high prairie
# Processing Record [record_count] of Set 5 | saleaula
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | puerto madryn
# Processing Record [record_count] of Set 5 | shima
# Processing Record [record_count] of Set 5 | kununurra
# Processing Record [record_count] of Set 5 | sibi
# Processing Record [record_count] of Set 5 | berdigestyakh
# Processing Record [record_count] of Set 5 | birao
# Processing Record [record_count] of Set 5 | evensk
# Processing Record [record_count] of Set 5 | qaqortoq
# Processing Record [record_count] of Set 5 | santa maria
# Processing Record [record_count] of Set 5 | vostok
# Processing Record [record_count] of Set 5 | pangil
# Processing Record [record_count] of Set 5 | ponta do sol
# Processing Record [record_count] of Set 5 | saint-philippe
# Processing Record [record_count] of Set 5 | bangsund
# Processing Record [record_count] of Set 5 | sumter
# Processing Record [record_count] of Set 5 | lethem
# Processing Record [record_count] of Set 5 | tavda
# Processing Record [record_count] of Set 5 | sao francisco
# Processing Record [record_count] of Set 5 | mayor pablo lagerenza
# Processing Record [record_count] of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | jamestown
# Processing Record [record_count] of Set 5 | morehead
# Processing Record [record_count] of Set 5 | east london
# Processing Record [record_count] of Set 5 | lamu
# Processing Record [record_count] of Set 5 | vanavara
# Processing Record [record_count] of Set 6 | patos
# Processing Record [record_count] of Set 6 | hamilton
# Processing Record [record_count] of Set 6 | ekimchan
# Processing Record [record_count] of Set 6 | presidencia roque saenz pena
# Processing Record [record_count] of Set 6 | moa
# Processing Record [record_count] of Set 6 | yelniki
# Processing Record [record_count] of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record [record_count] of Set 6 | high level
# Processing Record [record_count] of Set 6 | castro
# Processing Record [record_count] of Set 6 | alugan
# Processing Record [record_count] of Set 6 | nuuk
# Processing Record [record_count] of Set 6 | samarai
# Processing Record [record_count] of Set 6 | tessaoua
# Processing Record [record_count] of Set 6 | saint-junien
# Processing Record [record_count] of Set 6 | ust-uda
# Processing Record [record_count] of Set 6 | svetlyy
# Processing Record [record_count] of Set 6 | usogorsk
# Processing Record [record_count] of Set 6 | sur
# Processing Record [record_count] of Set 6 | acapulco
# Processing Record [record_count] of Set 6 | waw
# Processing Record [record_count] of Set 6 | egvekinot
# Processing Record [record_count] of Set 6 | mandera
# Processing Record [record_count] of Set 6 | altus
# Processing Record [record_count] of Set 6 | craig
# Processing Record [record_count] of Set 6 | paamiut
# Processing Record [record_count] of Set 6 | colares
# Processing Record [record_count] of Set 6 | kenora
# Processing Record [record_count] of Set 6 | wladyslawowo
# Processing Record [record_count] of Set 6 | saint-francois
# Processing Record [record_count] of Set 6 | mana
# Processing Record [record_count] of Set 6 | kozyatyn
# Processing Record [record_count] of Set 6 | palenque
# Processing Record [record_count] of Set 6 | port hardy
# Processing Record [record_count] of Set 6 | lembeni
# Processing Record [record_count] of Set 6 | warqla
# City not found. Skipping...
# Processing Record [record_count] of Set 6 | kiruna
# Processing Record [record_count] of Set 6 | brae
# Processing Record [record_count] of Set 6 | fort nelson
# Processing Record [record_count] of Set 6 | obninsk
# Processing Record [record_count] of Set 6 | sivaki
# Processing Record [record_count] of Set 6 | broome
# Processing Record [record_count] of Set 6 | makakilo city
# Processing Record [record_count] of Set 6 | camana
# Processing Record [record_count] of Set 6 | kuytun
# Processing Record [record_count] of Set 6 | jiangmen
# Processing Record [record_count] of Set 6 | manaure
# Processing Record [record_count] of Set 6 | taft
# Processing Record [record_count] of Set 6 | kloulklubed
# Processing Record [record_count] of Set 6 | gopalpur
# Processing Record [record_count] of Set 6 | jalu
# Processing Record [record_count] of Set 7 | college
# Processing Record [record_count] of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | road town
# Processing Record [record_count] of Set 7 | tay ninh
# Processing Record [record_count] of Set 7 | zabol
# Processing Record [record_count] of Set 7 | bardsir
# Processing Record [record_count] of Set 7 | caravelas
# Processing Record [record_count] of Set 7 | leh
# Processing Record [record_count] of Set 7 | antofagasta
# Processing Record [record_count] of Set 7 | chiguiri arriba
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | kasungu
# Processing Record [record_count] of Set 7 | pimentel
# Processing Record [record_count] of Set 7 | bafoulabe
# Processing Record [record_count] of Set 7 | sitka
# Processing Record [record_count] of Set 7 | luwingu
# Processing Record [record_count] of Set 7 | dikson
# Processing Record [record_count] of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | jumla
# Processing Record [record_count] of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | nome
# Processing Record [record_count] of Set 7 | araouane
# Processing Record [record_count] of Set 7 | clemson
# Processing Record [record_count] of Set 7 | panormos
# Processing Record [record_count] of Set 7 | lompoc
# Processing Record [record_count] of Set 7 | kyabe
# Processing Record [record_count] of Set 7 | bangui
# Processing Record [record_count] of Set 7 | roebourne
# Processing Record [record_count] of Set 7 | merauke
# Processing Record [record_count] of Set 7 | amuntai
# Processing Record [record_count] of Set 7 | altamont
# Processing Record [record_count] of Set 7 | tigil
# Processing Record [record_count] of Set 7 | levelland
# Processing Record [record_count] of Set 7 | quatre cocos
# Processing Record [record_count] of Set 7 | mackay
# Processing Record [record_count] of Set 7 | maragogi
# Processing Record [record_count] of Set 7 | fayaoue
# Processing Record [record_count] of Set 7 | tokur
# Processing Record [record_count] of Set 7 | bud
# Processing Record [record_count] of Set 7 | eldikan
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | alofi
# Processing Record [record_count] of Set 7 | christiana
# Processing Record [record_count] of Set 7 | the valley
# Processing Record [record_count] of Set 7 | ngunguru
# Processing Record [record_count] of Set 7 | arys
# Processing Record [record_count] of Set 7 | sohag
# Processing Record [record_count] of Set 7 | qasigiannguit
# Processing Record [record_count] of Set 7 | aswan
# Processing Record [record_count] of Set 7 | naze
# Processing Record [record_count] of Set 7 | agadez
# Processing Record [record_count] of Set 7 | tura
# Processing Record [record_count] of Set 8 | novyy urgal
# Processing Record [record_count] of Set 8 | is
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | isangel
# Processing Record [record_count] of Set 8 | lasa
# Processing Record [record_count] of Set 8 | zyryanka
# Processing Record [record_count] of Set 8 | ketchikan
# Processing Record [record_count] of Set 8 | qingan
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | jiddah
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | vilyuysk
# Processing Record [record_count] of Set 8 | talnakh
# Processing Record [record_count] of Set 8 | sheridan
# Processing Record [record_count] of Set 8 | lolua
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | ostrovnoy
# Processing Record [record_count] of Set 8 | kavieng
# Processing Record [record_count] of Set 8 | carutapera
# Processing Record [record_count] of Set 8 | maningrida
# Processing Record [record_count] of Set 8 | pundaguitan
# Processing Record [record_count] of Set 8 | kansanshi
# Processing Record [record_count] of Set 8 | bambanglipuro
# Processing Record [record_count] of Set 8 | belokurikha
# Processing Record [record_count] of Set 8 | atar
# Processing Record [record_count] of Set 8 | foligno
# Processing Record [record_count] of Set 8 | shimoda
# Processing Record [record_count] of Set 8 | bilma
# Processing Record [record_count] of Set 8 | la ronge
# Processing Record [record_count] of Set 8 | kampot
# Processing Record [record_count] of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | coquimbo
# Processing Record [record_count] of Set 8 | yichang
# Processing Record [record_count] of Set 8 | mount isa
# Processing Record [record_count] of Set 8 | satitoa
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | uppsala
# Processing Record [record_count] of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | nanortalik
# Processing Record [record_count] of Set 8 | kalmunai
# Processing Record [record_count] of Set 8 | tuatapere
# Processing Record [record_count] of Set 8 | san francisco
# Processing Record [record_count] of Set 8 | shuiji
# Processing Record [record_count] of Set 8 | dong hoi
# Processing Record [record_count] of Set 8 | tocopilla
# Processing Record [record_count] of Set 8 | roald
# Processing Record [record_count] of Set 8 | cartagena
# Processing Record [record_count] of Set 8 | yanan
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | mbandaka
# Processing Record [record_count] of Set 8 | mandal
# Processing Record [record_count] of Set 8 | asyut
# Processing Record [record_count] of Set 8 | awjilah
# Processing Record [record_count] of Set 8 | bathsheba
# Processing Record [record_count] of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | gamba
# Processing Record [record_count] of Set 9 | samusu
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | asau
# Processing Record [record_count] of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | matay
# Processing Record [record_count] of Set 9 | mbuguni
# Processing Record [record_count] of Set 9 | ternova
# Processing Record [record_count] of Set 9 | aklavik
# Processing Record [record_count] of Set 9 | eyl
# Processing Record [record_count] of Set 9 | nayoro
# Processing Record [record_count] of Set 9 | skibotn
# Processing Record [record_count] of Set 9 | yangshan
# Processing Record [record_count] of Set 9 | clyde
# Processing Record [record_count] of Set 9 | san ramon
# Processing Record [record_count] of Set 9 | chau doc
# Processing Record [record_count] of Set 9 | bangassou
# Processing Record [record_count] of Set 9 | husavik
# Processing Record [record_count] of Set 9 | dicabisagan
# Processing Record [record_count] of Set 9 | grand gaube
# Processing Record [record_count] of Set 9 | tazovskiy
# Processing Record [record_count] of Set 9 | casablanca
# Processing Record [record_count] of Set 9 | afmadu
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | idenao
# Processing Record [record_count] of Set 9 | marsh harbour
# Processing Record [record_count] of Set 9 | ahuimanu
# Processing Record [record_count] of Set 9 | kuching
# Processing Record [record_count] of Set 9 | safranbolu
# Processing Record [record_count] of Set 9 | poronaysk
# Processing Record [record_count] of Set 9 | langsa
# Processing Record [record_count] of Set 9 | simao
# Processing Record [record_count] of Set 9 | gabu
# Processing Record [record_count] of Set 9 | palmer
# Processing Record [record_count] of Set 9 | vastervik
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | boyolangu
# Processing Record [record_count] of Set 9 | touros
# Processing Record [record_count] of Set 9 | padang
# Processing Record [record_count] of Set 9 | riohacha
# Processing Record [record_count] of Set 9 | ekibastuz
# Processing Record [record_count] of Set 9 | mathbaria
# Processing Record [record_count] of Set 9 | kristiinankaupunki
# Processing Record [record_count] of Set 9 | chara
# Processing Record [record_count] of Set 9 | beloha
# Processing Record [record_count] of Set 9 | bo phloi
# Processing Record [record_count] of Set 9 | kuche
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | petropavlovka
# Processing Record [record_count] of Set 9 | mocajuba
# Processing Record [record_count] of Set 9 | bo
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | oktyabrskoye
# Processing Record [record_count] of Set 9 | matagami
# Processing Record [record_count] of Set 9 | russell
# Processing Record [record_count] of Set 9 | margate
# Processing Record [record_count] of Set 10 | wencheng
# Processing Record [record_count] of Set 10 | yakeshi
# Processing Record [record_count] of Set 10 | yazman
# Processing Record [record_count] of Set 10 | krasnoselkup
# Processing Record [record_count] of Set 10 | lazaro cardenas
# Processing Record [record_count] of Set 10 | yulara
# Processing Record [record_count] of Set 10 | nortelandia
# Processing Record [record_count] of Set 10 | talcahuano
# Processing Record [record_count] of Set 10 | sataua
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | vila franca do campo
# Processing Record [record_count] of Set 10 | lesnoy
# Processing Record [record_count] of Set 10 | banepa
# Processing Record [record_count] of Set 10 | vyzhnytsya
# Processing Record [record_count] of Set 10 | sinop
# Processing Record [record_count] of Set 10 | sobolevo
# Processing Record [record_count] of Set 10 | maxixe
# Processing Record [record_count] of Set 10 | hasaki
# Processing Record [record_count] of Set 10 | kovdor
# Processing Record [record_count] of Set 10 | kawana waters
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | itaueira
# Processing Record [record_count] of Set 10 | cabra
# Processing Record [record_count] of Set 10 | kampar
# Processing Record [record_count] of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | calama
# Processing Record [record_count] of Set 10 | tulungagung
# Processing Record [record_count] of Set 10 | nieuw amsterdam
# Processing Record [record_count] of Set 10 | taga
# Processing Record [record_count] of Set 10 | lashio
# Processing Record [record_count] of Set 10 | chirongui
# Processing Record [record_count] of Set 10 | guhagar
# Processing Record [record_count] of Set 10 | matara
# Processing Record [record_count] of Set 10 | jacareacanga
# Processing Record [record_count] of Set 10 | mirnyy
# Processing Record [record_count] of Set 10 | tarakan
# Processing Record [record_count] of Set 10 | kansay
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | north bend
# Processing Record [record_count] of Set 10 | chifeng
# Processing Record [record_count] of Set 10 | morris
# Processing Record [record_count] of Set 10 | lixourion
# Processing Record [record_count] of Set 10 | constitucion
# Processing Record [record_count] of Set 10 | ulagan
# Processing Record [record_count] of Set 10 | mongo
# Processing Record [record_count] of Set 10 | ulaangom
# Processing Record [record_count] of Set 10 | george
# Processing Record [record_count] of Set 10 | biak
# Processing Record [record_count] of Set 10 | koungheul
# Processing Record [record_count] of Set 10 | nguiu
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | kaduqli
# Processing Record [record_count] of Set 10 | coihaique
# Processing Record [record_count] of Set 10 | timizart
# Processing Record [record_count] of Set 11 | flin flon
# Processing Record [record_count] of Set 11 | soure
# Processing Record [record_count] of Set 11 | phan rang
# City not found. Skipping...
# Processing Record [record_count] of Set 11 | mosquera
# Processing Record [record_count] of Set 11 | chulym
# Processing Record [record_count] of Set 11 | molina
# Processing Record [record_count] of Set 11 | labutta
# City not found. Skipping...
# Processing Record [record_count] of Set 11 | taguatinga
# Processing Record [record_count] of Set 11 | saint-leu
# Processing Record [record_count] of Set 11 | saint-pierre
# Processing Record [record_count] of Set 11 | coolum beach
# Processing Record [record_count] of Set 11 | pori
# Processing Record [record_count] of Set 11 | arlit
# Processing Record [record_count] of Set 11 | wesley
# Processing Record [record_count] of Set 11 | aripuana
# Processing Record [record_count] of Set 11 | sumbawanga
# Processing Record [record_count] of Set 11 | opuwo
# Processing Record [record_count] of Set 11 | kesennuma
# City not found. Skipping...
# Processing Record [record_count] of Set 11 | tiznit
# Processing Record [record_count] of Set 11 | show low
# Processing Record [record_count] of Set 11 | elhovo
# Processing Record [record_count] of Set 11 | airai
# Processing Record [record_count] of Set 11 | sayyan
# Processing Record [record_count] of Set 11 | port hedland
# Processing Record [record_count] of Set 11 | ende
# Processing Record [record_count] of Set 11 | esso
# Processing Record [record_count] of Set 11 | wagga wagga
# Processing Record [record_count] of Set 11 | ningbo
# Processing Record [record_count] of Set 11 | san fernando
# Processing Record [record_count] of Set 11 | shizunai
# Processing Record [record_count] of Set 11 | komsomolskiy
# Processing Record [record_count] of Set 11 | sarh
# Processing Record [record_count] of Set 11 | tres arroyos
# Processing Record [record_count] of Set 11 | rudnya
# Processing Record [record_count] of Set 11 | cheremkhovo
# Processing Record [record_count] of Set 11 | puerto ayacucho
# Processing Record [record_count] of Set 11 | awbari
# Processing Record [record_count] of Set 11 | te anau
# Processing Record [record_count] of Set 11 | faanui
# Processing Record [record_count] of Set 11 | bontang
# Processing Record [record_count] of Set 11 | aljezur
# Processing Record [record_count] of Set 11 | sinazongwe
# Processing Record [record_count] of Set 11 | lakes entrance
# Processing Record [record_count] of Set 11 | tautira
# Processing Record [record_count] of Set 11 | griffith
# Processing Record [record_count] of Set 11 | albury
# Processing Record [record_count] of Set 11 | limulunga
# Processing Record [record_count] of Set 11 | puerto leguizamo
# Processing Record [record_count] of Set 11 | gushikawa
# Processing Record [record_count] of Set 11 | adiake
# Processing Record [record_count] of Set 12 | inhambane
# Processing Record [record_count] of Set 12 | norman
# Processing Record [record_count] of Set 12 | hihifo
# City not found. Skipping...
# Processing Record [record_count] of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record [record_count] of Set 12 | eureka
# Processing Record [record_count] of Set 12 | bayburt
# Processing Record [record_count] of Set 12 | mayo
# Processing Record [record_count] of Set 12 | nemuro
# Processing Record [record_count] of Set 12 | skelleftea
# Processing Record [record_count] of Set 12 | mount gambier
# Processing Record [record_count] of Set 12 | nyurba
# Processing Record [record_count] of Set 12 | sept-iles
# Processing Record [record_count] of Set 12 | sembe
# Processing Record [record_count] of Set 12 | movileni
# Processing Record [record_count] of Set 12 | codrington
# Processing Record [record_count] of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record [record_count] of Set 12 | mount hagen
# Processing Record [record_count] of Set 12 | abalak
# Processing Record [record_count] of Set 12 | nampula
# Processing Record [record_count] of Set 12 | auki
# Processing Record [record_count] of Set 12 | vuktyl
# Processing Record [record_count] of Set 12 | sultanpur
# Processing Record [record_count] of Set 12 | the pas
# Processing Record [record_count] of Set 12 | sorland
# Processing Record [record_count] of Set 12 | marcona
# City not found. Skipping...
# Processing Record [record_count] of Set 12 | pangkalanbuun
# Processing Record [record_count] of Set 12 | usakos
# Processing Record [record_count] of Set 12 | novoomskiy
# Processing Record [record_count] of Set 12 | meadow lake
# Processing Record [record_count] of Set 12 | kapit
# Processing Record [record_count] of Set 12 | general bravo
# Processing Record [record_count] of Set 12 | linxia
# Processing Record [record_count] of Set 12 | adrar
# Processing Record [record_count] of Set 12 | sao felix do xingu
# Processing Record [record_count] of Set 12 | weiser
# Processing Record [record_count] of Set 12 | santa barbara
# Processing Record [record_count] of Set 12 | yumen
# Processing Record [record_count] of Set 12 | wau
# Processing Record [record_count] of Set 12 | guerrero negro
# Processing Record [record_count] of Set 12 | oranjemund
# Processing Record [record_count] of Set 12 | kamiiso
# Processing Record [record_count] of Set 12 | la rioja
# Processing Record [record_count] of Set 12 | toamasina
# Processing Record [record_count] of Set 12 | hurghada
# Processing Record [record_count] of Set 12 | bubaque
# Processing Record [record_count] of Set 12 | tessalit
# Processing Record [record_count] of Set 12 | naantali
# Processing Record [record_count] of Set 12 | misratah
# Processing Record [record_count] of Set 12 | isabela
# Processing Record [record_count] of Set 12 | rio lindo
# Processing Record [record_count] of Set 13 | abu samrah
# Processing Record [record_count] of Set 13 | yanam
# Processing Record [record_count] of Set 13 | utiroa
# City not found. Skipping...
# Processing Record [record_count] of Set 13 | ginda
# Processing Record [record_count] of Set 13 | krasnyy chikoy
# Processing Record [record_count] of Set 13 | gari
# Processing Record [record_count] of Set 13 | grand-santi
# Processing Record [record_count] of Set 13 | gerash
# Processing Record [record_count] of Set 13 | vila velha
# Processing Record [record_count] of Set 13 | vyartsilya
# Processing Record [record_count] of Set 13 | igarka
# Processing Record [record_count] of Set 13 | aksarka
# Processing Record [record_count] of Set 13 | ucluelet
# Processing Record [record_count] of Set 13 | maki
# Processing Record [record_count] of Set 13 | whitehorse
# Processing Record [record_count] of Set 13 | ifakara
# Processing Record [record_count] of Set 13 | garowe
# Processing Record [record_count] of Set 13 | yeltsovka
# City not found. Skipping...
# Processing Record [record_count] of Set 13 | zholymbet
# Processing Record [record_count] of Set 13 | aleysk
# Processing Record [record_count] of Set 13 | woodward
# Processing Record [record_count] of Set 13 | kaabong
# Processing Record [record_count] of Set 13 | thinadhoo
# Processing Record [record_count] of Set 13 | lang suan
# Processing Record [record_count] of Set 13 | vila do maio
# Processing Record [record_count] of Set 13 | durban
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Busselton -33.6500  115.3333     57.07        76           9
# 1        Tuktoyaktuk  69.4541 -133.0374     37.65        97         100
# 2             Barrow  71.2906 -156.7887     37.42        87          40
# 3             Bethel  41.3712  -73.4140     72.52        83           0
# 4              Avera  33.1940  -82.5271     72.91        81          93
# 5    Arraial Do Cabo -22.9661  -42.0278     73.36        78           0
# 6            Salalah  17.0151   54.0924     78.89        89         100
# 7              Buala  -8.1450  159.5921     80.08        82          43
# 8  Sao Joao Da Barra -21.6403  -41.0511     73.49        72          18
# 9          Hauterive  46.0901    3.4459     83.16        29          55
#
#    Wind Speed Country                 Date
# 0        2.15      AU  2022-07-12 11:47:05
# 1       11.92      CA  2022-07-12 11:47:06
# 2        9.22      US  2022-07-12 11:47:06
# 3        5.75      US  2022-07-12 11:47:07
# 4        2.01      US  2022-07-12 11:47:07
# 5        9.22      BR  2022-07-12 11:47:08
# 6        8.05      OM  2022-07-12 11:47:08
# 7        5.97      SB  2022-07-12 11:47:08
# 8       11.27      BR  2022-07-12 11:47:09
# 9        6.89      FR  2022-07-12 11:47:09

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
new_city_df = city_data_df[new_column_order]
new_city_df.head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0    Busselton      AU  2022-07-12 11:47:05 -33.6500  115.3333     57.07
# 1  Tuktoyaktuk      CA  2022-07-12 11:47:06  69.4541 -133.0374     37.65
# 2       Barrow      US  2022-07-12 11:47:06  71.2906 -156.7887     37.42
# 3       Bethel      US  2022-07-12 11:47:07  41.3712  -73.4140     72.52
# 4        Avera      US  2022-07-12 11:47:07  33.1940  -82.5271     72.91
#
#    Humidity  Cloudiness  Wind Speed
# 0        76           9        2.15
# 1        97         100       11.92
# 2        87          40        9.22
# 3        83           0        5.75
# 4        81          93        2.01

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
