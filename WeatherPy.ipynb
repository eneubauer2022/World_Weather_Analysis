# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 630

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library

import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data=[]

# Print the beginning of the logging.
print("Beginning Data Retrieval       ")
print("--------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 == 0 and i >=50):
        set_count +=1
        record_count=1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url +"&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record [record_count] of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record [record_count] of Set 1 | zhanaozen
# Processing Record [record_count] of Set 1 | priego de cordoba
# Processing Record [record_count] of Set 1 | grootfontein
# Processing Record [record_count] of Set 1 | sola
# Processing Record [record_count] of Set 1 | khatanga
# Processing Record [record_count] of Set 1 | mataura
# Processing Record [record_count] of Set 1 | belize
# Processing Record [record_count] of Set 1 | puerto cabezas
# Processing Record [record_count] of Set 1 | rikitea
# Processing Record [record_count] of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | kapaa
# Processing Record [record_count] of Set 1 | vaini
# Processing Record [record_count] of Set 1 | atuona
# Processing Record [record_count] of Set 1 | ponta do sol
# Processing Record [record_count] of Set 1 | ushuaia
# Processing Record [record_count] of Set 1 | hilo
# Processing Record [record_count] of Set 1 | isangel
# Processing Record [record_count] of Set 1 | hermanus
# Processing Record [record_count] of Set 1 | longyearbyen
# Processing Record [record_count] of Set 1 | calama
# Processing Record [record_count] of Set 1 | cuamba
# Processing Record [record_count] of Set 1 | zaykovo
# Processing Record [record_count] of Set 1 | tebingtinggi
# Processing Record [record_count] of Set 1 | anadyr
# Processing Record [record_count] of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | elie
# Processing Record [record_count] of Set 1 | bundaberg
# Processing Record [record_count] of Set 1 | punta arenas
# Processing Record [record_count] of Set 1 | lethem
# Processing Record [record_count] of Set 1 | saint george
# Processing Record [record_count] of Set 1 | dudinka
# Processing Record [record_count] of Set 1 | busselton
# Processing Record [record_count] of Set 1 | puerto ayora
# Processing Record [record_count] of Set 1 | daokou
# Processing Record [record_count] of Set 1 | bichena
# Processing Record [record_count] of Set 1 | luderitz
# Processing Record [record_count] of Set 1 | honiara
# Processing Record [record_count] of Set 1 | sinnamary
# Processing Record [record_count] of Set 1 | albany
# Processing Record [record_count] of Set 1 | nouadhibou
# Processing Record [record_count] of Set 1 | kulhudhuffushi
# Processing Record [record_count] of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | torbay
# Processing Record [record_count] of Set 1 | matamoros
# Processing Record [record_count] of Set 1 | gaya
# Processing Record [record_count] of Set 1 | sao joao da barra
# Processing Record [record_count] of Set 1 | hobart
# Processing Record [record_count] of Set 1 | half moon bay
# Processing Record [record_count] of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | bluff
# Processing Record [record_count] of Set 2 | te horo
# Processing Record [record_count] of Set 2 | padang
# Processing Record [record_count] of Set 2 | tiksi
# Processing Record [record_count] of Set 2 | hithadhoo
# Processing Record [record_count] of Set 2 | tura
# Processing Record [record_count] of Set 2 | neiafu
# Processing Record [record_count] of Set 2 | the pas
# Processing Record [record_count] of Set 2 | manokwari
# Processing Record [record_count] of Set 2 | asbury park
# Processing Record [record_count] of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | chilca
# Processing Record [record_count] of Set 2 | annavasal
# Processing Record [record_count] of Set 2 | labrea
# Processing Record [record_count] of Set 2 | biak
# Processing Record [record_count] of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | east london
# Processing Record [record_count] of Set 2 | katsuura
# Processing Record [record_count] of Set 2 | noumea
# Processing Record [record_count] of Set 2 | saint-philippe
# Processing Record [record_count] of Set 2 | meilu
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | jamestown
# Processing Record [record_count] of Set 2 | butaritari
# Processing Record [record_count] of Set 2 | korem
# Processing Record [record_count] of Set 2 | saint-georges
# Processing Record [record_count] of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | paralimni
# Processing Record [record_count] of Set 2 | severo-kurilsk
# Processing Record [record_count] of Set 2 | paramonga
# Processing Record [record_count] of Set 2 | perene
# Processing Record [record_count] of Set 2 | flinders
# Processing Record [record_count] of Set 2 | port hedland
# Processing Record [record_count] of Set 2 | airai
# Processing Record [record_count] of Set 2 | chokurdakh
# Processing Record [record_count] of Set 2 | ajaccio
# Processing Record [record_count] of Set 2 | cape town
# Processing Record [record_count] of Set 2 | tocopilla
# Processing Record [record_count] of Set 2 | karaul
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | plaster rock
# Processing Record [record_count] of Set 2 | pangody
# Processing Record [record_count] of Set 2 | kuche
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | madison
# Processing Record [record_count] of Set 2 | grindavik
# Processing Record [record_count] of Set 2 | raudeberg
# Processing Record [record_count] of Set 2 | marawi
# Processing Record [record_count] of Set 2 | saskylakh
# Processing Record [record_count] of Set 2 | tessalit
# Processing Record [record_count] of Set 2 | kyzyl
# Processing Record [record_count] of Set 2 | burns lake
# Processing Record [record_count] of Set 2 | cabo san lucas
# Processing Record [record_count] of Set 2 | tabuk
# Processing Record [record_count] of Set 3 | yerofey pavlovich
# Processing Record [record_count] of Set 3 | tuatapere
# Processing Record [record_count] of Set 3 | sarankhola
# Processing Record [record_count] of Set 3 | nizhniy kuranakh
# Processing Record [record_count] of Set 3 | yellowknife
# Processing Record [record_count] of Set 3 | bijar
# Processing Record [record_count] of Set 3 | tautira
# Processing Record [record_count] of Set 3 | mount gambier
# Processing Record [record_count] of Set 3 | amderma
# City not found. Skipping...
# Processing Record [record_count] of Set 3 | klaksvik
# Processing Record [record_count] of Set 3 | new norfolk
# Processing Record [record_count] of Set 3 | katha
# City not found. Skipping...
# Processing Record [record_count] of Set 3 | bredasdorp
# Processing Record [record_count] of Set 3 | baruun-urt
# Processing Record [record_count] of Set 3 | passo de camaragibe
# Processing Record [record_count] of Set 3 | fukue
# Processing Record [record_count] of Set 3 | bodmin
# Processing Record [record_count] of Set 3 | big spring
# Processing Record [record_count] of Set 3 | jumla
# Processing Record [record_count] of Set 3 | merrill
# Processing Record [record_count] of Set 3 | sumenep
# Processing Record [record_count] of Set 3 | port elizabeth
# Processing Record [record_count] of Set 3 | qaanaaq
# Processing Record [record_count] of Set 3 | balikpapan
# Processing Record [record_count] of Set 3 | kaitangata
# Processing Record [record_count] of Set 3 | cherskiy
# Processing Record [record_count] of Set 3 | sindhnur
# Processing Record [record_count] of Set 3 | byron bay
# Processing Record [record_count] of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record [record_count] of Set 3 | saldanha
# Processing Record [record_count] of Set 3 | kawana waters
# City not found. Skipping...
# Processing Record [record_count] of Set 3 | nanortalik
# Processing Record [record_count] of Set 3 | bilibino
# Processing Record [record_count] of Set 3 | port alfred
# Processing Record [record_count] of Set 3 | provideniya
# Processing Record [record_count] of Set 3 | esperance
# Processing Record [record_count] of Set 3 | sitka
# Processing Record [record_count] of Set 3 | cardston
# Processing Record [record_count] of Set 3 | port hardy
# Processing Record [record_count] of Set 3 | chuy
# Processing Record [record_count] of Set 3 | barrow
# Processing Record [record_count] of Set 3 | tuktoyaktuk
# Processing Record [record_count] of Set 3 | goure
# Processing Record [record_count] of Set 3 | mehamn
# Processing Record [record_count] of Set 3 | brodokalmak
# Processing Record [record_count] of Set 3 | nikolskoye
# Processing Record [record_count] of Set 3 | shenzhen
# Processing Record [record_count] of Set 3 | hamilton
# Processing Record [record_count] of Set 3 | muisne
# Processing Record [record_count] of Set 3 | menongue
# Processing Record [record_count] of Set 4 | dzaoudzi
# Processing Record [record_count] of Set 4 | naryan-mar
# Processing Record [record_count] of Set 4 | mezen
# Processing Record [record_count] of Set 4 | tehachapi
# Processing Record [record_count] of Set 4 | nago
# Processing Record [record_count] of Set 4 | inhambane
# Processing Record [record_count] of Set 4 | sheregesh
# Processing Record [record_count] of Set 4 | ahipara
# Processing Record [record_count] of Set 4 | hualmay
# Processing Record [record_count] of Set 4 | maiduguri
# Processing Record [record_count] of Set 4 | dikson
# Processing Record [record_count] of Set 4 | srivardhan
# Processing Record [record_count] of Set 4 | talnakh
# Processing Record [record_count] of Set 4 | inirida
# Processing Record [record_count] of Set 4 | pangnirtung
# Processing Record [record_count] of Set 4 | lebu
# Processing Record [record_count] of Set 4 | kahului
# Processing Record [record_count] of Set 4 | hohhot
# Processing Record [record_count] of Set 4 | fougamou
# Processing Record [record_count] of Set 4 | baneh
# Processing Record [record_count] of Set 4 | bengkulu
# Processing Record [record_count] of Set 4 | hobyo
# Processing Record [record_count] of Set 4 | bjornevatn
# Processing Record [record_count] of Set 4 | santa isabel do rio negro
# Processing Record [record_count] of Set 4 | georgetown
# Processing Record [record_count] of Set 4 | camopi
# Processing Record [record_count] of Set 4 | evensk
# Processing Record [record_count] of Set 4 | bethel
# Processing Record [record_count] of Set 4 | dalbandin
# Processing Record [record_count] of Set 4 | stornoway
# Processing Record [record_count] of Set 4 | nanakuli
# Processing Record [record_count] of Set 4 | warrington
# Processing Record [record_count] of Set 4 | port macquarie
# Processing Record [record_count] of Set 4 | ati
# Processing Record [record_count] of Set 4 | ribeira grande
# Processing Record [record_count] of Set 4 | antofagasta
# Processing Record [record_count] of Set 4 | tucson
# Processing Record [record_count] of Set 4 | castlemaine
# Processing Record [record_count] of Set 4 | ozark
# Processing Record [record_count] of Set 4 | ngaoundere
# Processing Record [record_count] of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record [record_count] of Set 4 | umkomaas
# Processing Record [record_count] of Set 4 | carnarvon
# Processing Record [record_count] of Set 4 | fare
# Processing Record [record_count] of Set 4 | kodiak
# Processing Record [record_count] of Set 4 | aklavik
# Processing Record [record_count] of Set 4 | longlac
# City not found. Skipping...
# Processing Record [record_count] of Set 4 | horsham
# Processing Record [record_count] of Set 4 | bowen
# Processing Record [record_count] of Set 4 | tasiilaq
# Processing Record [record_count] of Set 5 | ust-tsilma
# Processing Record [record_count] of Set 5 | samarai
# Processing Record [record_count] of Set 5 | hasaki
# Processing Record [record_count] of Set 5 | camabatela
# Processing Record [record_count] of Set 5 | itoman
# Processing Record [record_count] of Set 5 | vao
# Processing Record [record_count] of Set 5 | kruisfontein
# Processing Record [record_count] of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | geraldton
# Processing Record [record_count] of Set 5 | celestun
# Processing Record [record_count] of Set 5 | batemans bay
# Processing Record [record_count] of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | constitucion
# Processing Record [record_count] of Set 5 | tazovskiy
# Processing Record [record_count] of Set 5 | san patricio
# Processing Record [record_count] of Set 5 | sambava
# Processing Record [record_count] of Set 5 | huaicheng
# Processing Record [record_count] of Set 5 | alta floresta
# Processing Record [record_count] of Set 5 | hami
# Processing Record [record_count] of Set 5 | soto la marina
# Processing Record [record_count] of Set 5 | ziro
# Processing Record [record_count] of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | klyuchi
# Processing Record [record_count] of Set 5 | east hemet
# Processing Record [record_count] of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | avarua
# Processing Record [record_count] of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | twentynine palms
# Processing Record [record_count] of Set 5 | cururupu
# Processing Record [record_count] of Set 5 | savalou
# Processing Record [record_count] of Set 5 | bambous virieux
# Processing Record [record_count] of Set 5 | murdochville
# Processing Record [record_count] of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | kurchum
# Processing Record [record_count] of Set 5 | luza
# Processing Record [record_count] of Set 5 | riyadh
# Processing Record [record_count] of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | lavrentiya
# Processing Record [record_count] of Set 5 | thessalon
# Processing Record [record_count] of Set 5 | gizo
# Processing Record [record_count] of Set 5 | kikwit
# Processing Record [record_count] of Set 5 | ilulissat
# Processing Record [record_count] of Set 5 | haimen
# Processing Record [record_count] of Set 5 | yantal
# Processing Record [record_count] of Set 5 | moratuwa
# Processing Record [record_count] of Set 5 | juneau
# Processing Record [record_count] of Set 5 | namatanai
# Processing Record [record_count] of Set 5 | kaeo
# Processing Record [record_count] of Set 5 | edeia
# Processing Record [record_count] of Set 5 | iranshahr
# Processing Record [record_count] of Set 6 | san cristobal
# Processing Record [record_count] of Set 6 | peniche
# Processing Record [record_count] of Set 6 | kununurra
# Processing Record [record_count] of Set 6 | iracoubo
# Processing Record [record_count] of Set 6 | huilong
# Processing Record [record_count] of Set 6 | latung
# Processing Record [record_count] of Set 6 | kassala
# Processing Record [record_count] of Set 6 | kovur
# Processing Record [record_count] of Set 6 | mar del plata
# Processing Record [record_count] of Set 6 | yen bai
# Processing Record [record_count] of Set 6 | batagay
# Processing Record [record_count] of Set 6 | vila franca do campo
# Processing Record [record_count] of Set 6 | okhotsk
# Processing Record [record_count] of Set 6 | praia da vitoria
# Processing Record [record_count] of Set 6 | castro
# Processing Record [record_count] of Set 6 | poum
# Processing Record [record_count] of Set 6 | la rioja
# Processing Record [record_count] of Set 6 | dunajska streda
# Processing Record [record_count] of Set 6 | tambun
# Processing Record [record_count] of Set 6 | baghdad
# Processing Record [record_count] of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record [record_count] of Set 6 | north bend
# Processing Record [record_count] of Set 6 | camargo
# Processing Record [record_count] of Set 6 | lasa
# Processing Record [record_count] of Set 6 | faya
# Processing Record [record_count] of Set 6 | syedove
# Processing Record [record_count] of Set 6 | lagoa
# Processing Record [record_count] of Set 6 | souillac
# Processing Record [record_count] of Set 6 | kloulklubed
# Processing Record [record_count] of Set 6 | san quintin
# Processing Record [record_count] of Set 6 | opuwo
# Processing Record [record_count] of Set 6 | toamasina
# Processing Record [record_count] of Set 6 | victoria
# Processing Record [record_count] of Set 6 | bilma
# Processing Record [record_count] of Set 6 | iqaluit
# Processing Record [record_count] of Set 6 | trairi
# Processing Record [record_count] of Set 6 | kralendijk
# Processing Record [record_count] of Set 6 | meulaboh
# Processing Record [record_count] of Set 6 | henties bay
# Processing Record [record_count] of Set 6 | mozarlandia
# Processing Record [record_count] of Set 6 | hofn
# Processing Record [record_count] of Set 6 | puerto leguizamo
# Processing Record [record_count] of Set 6 | labutta
# City not found. Skipping...
# Processing Record [record_count] of Set 6 | talcahuano
# Processing Record [record_count] of Set 6 | langxiang
# Processing Record [record_count] of Set 6 | kuandian
# Processing Record [record_count] of Set 6 | lerwick
# Processing Record [record_count] of Set 6 | looc
# Processing Record [record_count] of Set 6 | pringsewu
# Processing Record [record_count] of Set 6 | mahenge
# Processing Record [record_count] of Set 7 | chala
# Processing Record [record_count] of Set 7 | nelson bay
# Processing Record [record_count] of Set 7 | safakulevo
# Processing Record [record_count] of Set 7 | sabang
# Processing Record [record_count] of Set 7 | wamba
# Processing Record [record_count] of Set 7 | methven
# Processing Record [record_count] of Set 7 | havoysund
# Processing Record [record_count] of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | lolua
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | vanimo
# Processing Record [record_count] of Set 7 | avera
# Processing Record [record_count] of Set 7 | sao filipe
# Processing Record [record_count] of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | makinsk
# Processing Record [record_count] of Set 7 | faanui
# Processing Record [record_count] of Set 7 | ostrovnoy
# Processing Record [record_count] of Set 7 | vaovai
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | hamada
# Processing Record [record_count] of Set 7 | saint-joseph
# Processing Record [record_count] of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | bubaque
# Processing Record [record_count] of Set 7 | pevek
# Processing Record [record_count] of Set 7 | raichur
# Processing Record [record_count] of Set 7 | beringovskiy
# Processing Record [record_count] of Set 7 | annonay
# Processing Record [record_count] of Set 7 | haines junction
# Processing Record [record_count] of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | upernavik
# Processing Record [record_count] of Set 7 | cabedelo
# Processing Record [record_count] of Set 7 | toora-khem
# Processing Record [record_count] of Set 7 | los llanos de aridane
# Processing Record [record_count] of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | kroya
# Processing Record [record_count] of Set 7 | kushima
# Processing Record [record_count] of Set 7 | samusu
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | sabha
# Processing Record [record_count] of Set 7 | cockburn town
# Processing Record [record_count] of Set 7 | the valley
# Processing Record [record_count] of Set 7 | kastamonu
# Processing Record [record_count] of Set 7 | kamenka
# Processing Record [record_count] of Set 7 | catabola
# Processing Record [record_count] of Set 7 | marcona
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | skeldon
# Processing Record [record_count] of Set 7 | puerto del rosario
# Processing Record [record_count] of Set 7 | kayerkan
# Processing Record [record_count] of Set 7 | mount isa
# Processing Record [record_count] of Set 7 | murupara
# Processing Record [record_count] of Set 7 | general roca
# Processing Record [record_count] of Set 7 | beloha
# Processing Record [record_count] of Set 7 | aipe
# Processing Record [record_count] of Set 8 | yelan-koleno
# Processing Record [record_count] of Set 8 | ancud
# Processing Record [record_count] of Set 8 | touros
# Processing Record [record_count] of Set 8 | cap malheureux
# Processing Record [record_count] of Set 8 | sazonovo
# Processing Record [record_count] of Set 8 | solok
# Processing Record [record_count] of Set 8 | eisenhuttenstadt
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | laguna
# Processing Record [record_count] of Set 8 | thinadhoo
# Processing Record [record_count] of Set 8 | kavieng
# Processing Record [record_count] of Set 8 | bari
# Processing Record [record_count] of Set 8 | mahebourg
# Processing Record [record_count] of Set 8 | bella vista
# Processing Record [record_count] of Set 8 | yar-sale
# Processing Record [record_count] of Set 8 | shimoda
# Processing Record [record_count] of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | kuybyshevo
# Processing Record [record_count] of Set 8 | nyaunglebin
# Processing Record [record_count] of Set 8 | pleasanton
# Processing Record [record_count] of Set 8 | husavik
# Processing Record [record_count] of Set 8 | codrington
# Processing Record [record_count] of Set 8 | akonolinga
# Processing Record [record_count] of Set 8 | ferrol
# Processing Record [record_count] of Set 8 | port shepstone
# Processing Record [record_count] of Set 8 | voyvozh
# Processing Record [record_count] of Set 8 | havelock
# Processing Record [record_count] of Set 8 | hay river
# Processing Record [record_count] of Set 8 | vanavara
# Processing Record [record_count] of Set 8 | tiruchchendur
# Processing Record [record_count] of Set 8 | medicine hat
# Processing Record [record_count] of Set 8 | tucuman
# Processing Record [record_count] of Set 8 | nome
# Processing Record [record_count] of Set 8 | coquimbo
# Processing Record [record_count] of Set 8 | mocambique
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | olinda
# Processing Record [record_count] of Set 8 | aksu
# Processing Record [record_count] of Set 8 | okha
# Processing Record [record_count] of Set 8 | yomitan
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | bongor
# Processing Record [record_count] of Set 8 | san andres
# Processing Record [record_count] of Set 8 | sakakah
# Processing Record [record_count] of Set 8 | nha trang
# Processing Record [record_count] of Set 8 | carutapera
# Processing Record [record_count] of Set 8 | mayumba
# Processing Record [record_count] of Set 8 | log
# Processing Record [record_count] of Set 8 | tucuma
# Processing Record [record_count] of Set 8 | mahibadhoo
# Processing Record [record_count] of Set 8 | parry sound
# Processing Record [record_count] of Set 8 | balkhash
# Processing Record [record_count] of Set 8 | bambamarca
# Processing Record [record_count] of Set 9 | ambilobe
# Processing Record [record_count] of Set 9 | robertsport
# Processing Record [record_count] of Set 9 | graham
# Processing Record [record_count] of Set 9 | tombouctou
# Processing Record [record_count] of Set 9 | phalombe
# Processing Record [record_count] of Set 9 | camacha
# Processing Record [record_count] of Set 9 | chapais
# Processing Record [record_count] of Set 9 | dunda
# Processing Record [record_count] of Set 9 | taber
# Processing Record [record_count] of Set 9 | leningradskiy
# Processing Record [record_count] of Set 9 | bol
# Processing Record [record_count] of Set 9 | paamiut
# Processing Record [record_count] of Set 9 | caraballeda
# Processing Record [record_count] of Set 9 | naze
# Processing Record [record_count] of Set 9 | rurrenabaque
# Processing Record [record_count] of Set 9 | gaoua
# Processing Record [record_count] of Set 9 | oistins
# Processing Record [record_count] of Set 9 | muros
# Processing Record [record_count] of Set 9 | barbar
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | fairview
# Processing Record [record_count] of Set 9 | bandarbeyla
# Processing Record [record_count] of Set 9 | aswan
# Processing Record [record_count] of Set 9 | ojinaga
# Processing Record [record_count] of Set 9 | poquoson
# Processing Record [record_count] of Set 9 | dmitriyev-lgovskiy
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | manggar
# Processing Record [record_count] of Set 9 | makhachkala
# Processing Record [record_count] of Set 9 | artyom
# Processing Record [record_count] of Set 9 | wewak
# Processing Record [record_count] of Set 9 | lata
# Processing Record [record_count] of Set 9 | along
# Processing Record [record_count] of Set 9 | tuapse
# Processing Record [record_count] of Set 9 | gigmoto
# Processing Record [record_count] of Set 9 | estacion coahuila
# Processing Record [record_count] of Set 9 | ucluelet
# Processing Record [record_count] of Set 9 | anaco
# Processing Record [record_count] of Set 9 | mackay
# Processing Record [record_count] of Set 9 | khonuu
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | yulara
# Processing Record [record_count] of Set 9 | conde
# Processing Record [record_count] of Set 9 | sapa
# Processing Record [record_count] of Set 9 | bay roberts
# Processing Record [record_count] of Set 9 | sangar
# Processing Record [record_count] of Set 9 | yining
# Processing Record [record_count] of Set 9 | tornio
# Processing Record [record_count] of Set 9 | peterhead
# Processing Record [record_count] of Set 9 | paez
# Processing Record [record_count] of Set 9 | ballina
# Processing Record [record_count] of Set 9 | sidney
# Processing Record [record_count] of Set 9 | tahta
# Processing Record [record_count] of Set 10 | cidreira
# Processing Record [record_count] of Set 10 | longyan
# Processing Record [record_count] of Set 10 | port augusta
# Processing Record [record_count] of Set 10 | caravelas
# Processing Record [record_count] of Set 10 | wau
# Processing Record [record_count] of Set 10 | broome
# Processing Record [record_count] of Set 10 | banda aceh
# Processing Record [record_count] of Set 10 | maridi
# Processing Record [record_count] of Set 10 | eregli
# Processing Record [record_count] of Set 10 | port lincoln
# Processing Record [record_count] of Set 10 | tawnat
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | christchurch
# Processing Record [record_count] of Set 10 | aiken
# Processing Record [record_count] of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | zhangye
# Processing Record [record_count] of Set 10 | kontagora
# Processing Record [record_count] of Set 10 | iberia
# Processing Record [record_count] of Set 10 | burnie
# Processing Record [record_count] of Set 10 | pemberton
# Processing Record [record_count] of Set 10 | amahai
# Processing Record [record_count] of Set 10 | grand gaube
# Processing Record [record_count] of Set 10 | norman wells
# Processing Record [record_count] of Set 10 | thompson
# Processing Record [record_count] of Set 10 | batagay-alyta
# Processing Record [record_count] of Set 10 | olafsvik
# Processing Record [record_count] of Set 10 | belyy yar
# Processing Record [record_count] of Set 10 | domoni
# Processing Record [record_count] of Set 10 | kushmurun
# Processing Record [record_count] of Set 10 | waupun
# Processing Record [record_count] of Set 10 | trofors
# Processing Record [record_count] of Set 10 | redmond
# Processing Record [record_count] of Set 10 | ribeira brava
# Processing Record [record_count] of Set 10 | sao miguel do oeste
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | knysna
# Processing Record [record_count] of Set 10 | margate
# Processing Record [record_count] of Set 10 | paradwip
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | le port
# Processing Record [record_count] of Set 10 | lorengau
# Processing Record [record_count] of Set 10 | saint-louis
# Processing Record [record_count] of Set 10 | krasnyy yar
# Processing Record [record_count] of Set 10 | burica
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | agnibilekrou
# Processing Record [record_count] of Set 10 | auki
# Processing Record [record_count] of Set 10 | chingirlau
# Processing Record [record_count] of Set 10 | basco
# Processing Record [record_count] of Set 10 | kahuta
# Processing Record [record_count] of Set 10 | freeport
# Processing Record [record_count] of Set 10 | dunedin
# Processing Record [record_count] of Set 10 | dongtai
# Processing Record [record_count] of Set 10 | heers
# Processing Record [record_count] of Set 11 | leshukonskoye
# Processing Record [record_count] of Set 11 | sao pedro do sul
# Processing Record [record_count] of Set 11 | springfield
# Processing Record [record_count] of Set 11 | dzilam gonzalez
# Processing Record [record_count] of Set 11 | marsa matruh
# Processing Record [record_count] of Set 11 | asyut
# Processing Record [record_count] of Set 11 | pisco
# Processing Record [record_count] of Set 11 | amudat
# Processing Record [record_count] of Set 11 | asau
# Processing Record [record_count] of Set 11 | truro
# Processing Record [record_count] of Set 11 | mabaruma
# Processing Record [record_count] of Set 11 | warwick
# Processing Record [record_count] of Set 11 | boralday
# Processing Record [record_count] of Set 11 | esmeraldas
# Processing Record [record_count] of Set 11 | grand-lahou
# Processing Record [record_count] of Set 11 | tabas
# Processing Record [record_count] of Set 11 | naruto
# Processing Record [record_count] of Set 11 | ternovka
# Processing Record [record_count] of Set 11 | rio gallegos
# Processing Record [record_count] of Set 11 | kokkola
# Processing Record [record_count] of Set 11 | balykshi
# Processing Record [record_count] of Set 11 | vestmannaeyjar
# Processing Record [record_count] of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record [record_count] of Set 11 | richards bay
# Processing Record [record_count] of Set 11 | raymond terrace
# Processing Record [record_count] of Set 11 | gwanda
# Processing Record [record_count] of Set 11 | altamira
# Processing Record [record_count] of Set 11 | salinopolis
# Processing Record [record_count] of Set 11 | killybegs
# Processing Record [record_count] of Set 11 | thunder bay
# Processing Record [record_count] of Set 11 | lusambo
# Processing Record [record_count] of Set 11 | clyde river
# Processing Record [record_count] of Set 11 | adrar
# Processing Record [record_count] of Set 11 | ngunguru
# Processing Record [record_count] of Set 11 | gataivai
# Processing Record [record_count] of Set 11 | bereda
# Processing Record [record_count] of Set 11 | copiapo
# Processing Record [record_count] of Set 11 | vostok
# Processing Record [record_count] of Set 11 | prieska
# Processing Record [record_count] of Set 11 | ferai
# City not found. Skipping...
# Processing Record [record_count] of Set 11 | coahuayana
# Processing Record [record_count] of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record [record_count] of Set 11 | arlit
# Processing Record [record_count] of Set 11 | coihaique
# Processing Record [record_count] of Set 11 | lhokseumawe
# Processing Record [record_count] of Set 11 | sosnovo-ozerskoye
# Processing Record [record_count] of Set 11 | sylva
# Processing Record [record_count] of Set 11 | at-bashi
# Processing Record [record_count] of Set 11 | masjed-e soleyman
# City not found. Skipping...
# Processing Record [record_count] of Set 11 | presidencia roque saenz pena
# Processing Record [record_count] of Set 12 | saleaula
# City not found. Skipping...
# Processing Record [record_count] of Set 12 | la ronge
# Processing Record [record_count] of Set 12 | pangkalanbuun
# Processing Record [record_count] of Set 12 | rocha
# Processing Record [record_count] of Set 12 | mindelo
# Processing Record [record_count] of Set 12 | guerrero negro
# Processing Record [record_count] of Set 12 | atikokan
# Processing Record [record_count] of Set 12 | parana
# Processing Record [record_count] of Set 12 | dubai
# Processing Record [record_count] of Set 12 | buala
# Processing Record [record_count] of Set 12 | bouca
# Processing Record [record_count] of Set 12 | arraial do cabo
# Processing Record [record_count] of Set 12 | alanya
# Processing Record [record_count] of Set 12 | kousseri
# Processing Record [record_count] of Set 12 | phaltan
# Processing Record [record_count] of Set 12 | tawang
# Processing Record [record_count] of Set 12 | viana
# Processing Record [record_count] of Set 12 | moindou
# Processing Record [record_count] of Set 12 | monroe
# Processing Record [record_count] of Set 12 | russell
# Processing Record [record_count] of Set 12 | gikalo
# City not found. Skipping...
# Processing Record [record_count] of Set 12 | viransehir
# Processing Record [record_count] of Set 12 | moyobamba
# Processing Record [record_count] of Set 12 | zyryanka
# Processing Record [record_count] of Set 12 | egvekinot
# Processing Record [record_count] of Set 12 | sao felix do xingu
# Processing Record [record_count] of Set 12 | palenque
# Processing Record [record_count] of Set 12 | conceicao do araguaia
# Processing Record [record_count] of Set 12 | belaguntha
# Processing Record [record_count] of Set 12 | villarrica
# Processing Record [record_count] of Set 12 | barguzin
# Processing Record [record_count] of Set 12 | cervignano del friuli
# Processing Record [record_count] of Set 12 | san jose
# Processing Record [record_count] of Set 12 | baykit
# Processing Record [record_count] of Set 12 | ust-nera
# Processing Record [record_count] of Set 12 | qaqortoq
# Processing Record [record_count] of Set 12 | quelimane
# Processing Record [record_count] of Set 12 | garut
# Processing Record [record_count] of Set 12 | colimes
# Processing Record [record_count] of Set 12 | turukhansk
# Processing Record [record_count] of Set 12 | yakeshi
# Processing Record [record_count] of Set 12 | karratha
# Processing Record [record_count] of Set 12 | tuensang
# Processing Record [record_count] of Set 12 | shache
# Processing Record [record_count] of Set 12 | ixtapa
# Processing Record [record_count] of Set 12 | santiago
# Processing Record [record_count] of Set 12 | sistranda
# Processing Record [record_count] of Set 12 | kapit
# Processing Record [record_count] of Set 12 | sao domingos do prata
# Processing Record [record_count] of Set 12 | chalmette
# Processing Record [record_count] of Set 13 | soyo
# Processing Record [record_count] of Set 13 | sydney
# Processing Record [record_count] of Set 13 | maryville
# Processing Record [record_count] of Set 13 | port-gentil
# Processing Record [record_count] of Set 13 | bagula
# Processing Record [record_count] of Set 13 | sibolga
# Processing Record [record_count] of Set 13 | panzhihua
# Processing Record [record_count] of Set 13 | rawson
# Processing Record [record_count] of Set 13 | oktyabrskoye
# Processing Record [record_count] of Set 13 | mazyr
# Processing Record [record_count] of Set 13 | maldonado
# Processing Record [record_count] of Set 13 | phan thiet
# Processing Record [record_count] of Set 13 | nyrob
# Processing Record [record_count] of Set 13 | ayan
# Processing Record [record_count] of Set 13 | bonavista
# Processing Record [record_count] of Set 13 | yashkul
# Processing Record [record_count] of Set 13 | utiroa
# City not found. Skipping...
# Processing Record [record_count] of Set 13 | methoni
# Processing Record [record_count] of Set 13 | portland
# Processing Record [record_count] of Set 13 | abu kamal
# Processing Record [record_count] of Set 13 | nguru
# Processing Record [record_count] of Set 13 | saint anthony
# Processing Record [record_count] of Set 13 | amli
# Processing Record [record_count] of Set 13 | bulembu
# Processing Record [record_count] of Set 13 | narsaq
# Processing Record [record_count] of Set 13 | balclutha
# Processing Record [record_count] of Set 13 | kotelnikovo
# Processing Record [record_count] of Set 13 | dingle
# Processing Record [record_count] of Set 13 | gelemso
# Processing Record [record_count] of Set 13 | palmer
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Zhanaozen  43.3000   52.8000     78.87        29           0
# 1  Priego De Cordoba  37.4381   -4.1952     73.26        30           1
# 2       Grootfontein -19.5667   18.1167     38.77        75           0
# 3               Sola -13.8833  167.5500     80.06        78          16
# 4           Khatanga  71.9667  102.5000     37.22        97         100
# 5            Mataura -46.1927  168.8643     45.48        90         100
# 6             Belize  17.2500  -88.7500     82.72        96         100
# 7     Puerto Cabezas  14.0351  -83.3888     78.35        90         100
# 8            Rikitea -23.1203 -134.9692     74.71        73           0
# 9              Kapaa  22.0752 -159.3190     85.98        68          40
#
#    Wind Speed Country                 Date
# 0        9.86      KZ  2022-07-12 01:45:14
# 1        5.66      ES  2022-07-12 01:45:15
# 2        1.14      NA  2022-07-12 01:45:15
# 3       15.57      VU  2022-07-12 01:45:15
# 4       12.30      RU  2022-07-12 01:45:16
# 5       10.16      NZ  2022-07-12 01:45:16
# 6        2.82      BZ  2022-07-12 01:40:42
# 7        9.84      NI  2022-07-12 01:45:16
# 8       12.24      PF  2022-07-12 01:45:17
# 9       12.66      US  2022-07-12 01:45:17

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
new_city_df = city_data_df[new_column_order]
new_city_df.head()
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0          Zhanaozen      KZ  2022-07-12 01:45:14  43.3000   52.8000
# 1  Priego De Cordoba      ES  2022-07-12 01:45:15  37.4381   -4.1952
# 2       Grootfontein      NA  2022-07-12 01:45:15 -19.5667   18.1167
# 3               Sola      VU  2022-07-12 01:45:15 -13.8833  167.5500
# 4           Khatanga      RU  2022-07-12 01:45:16  71.9667  102.5000
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     78.87        29           0        9.86
# 1     73.26        30           1        5.66
# 2     38.77        75           0        1.14
# 3     80.06        78          16       15.57
# 4     37.22        97         100       12.30

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
