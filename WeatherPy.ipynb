# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 611

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library

import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data=[]

# Print the beginning of the logging.
print("Beginning Data Retrieval       ")
print("--------------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 == 0 and i >=50):
        set_count +=1
        record_count=1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url +"&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record [record_count] of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record [record_count] of Set 1 | carnarvon
# Processing Record [record_count] of Set 1 | gazalkent
# Processing Record [record_count] of Set 1 | pangnirtung
# Processing Record [record_count] of Set 1 | deputatskiy
# Processing Record [record_count] of Set 1 | dikson
# Processing Record [record_count] of Set 1 | nikolskoye
# Processing Record [record_count] of Set 1 | lompoc
# Processing Record [record_count] of Set 1 | mar del plata
# Processing Record [record_count] of Set 1 | taksimo
# Processing Record [record_count] of Set 1 | aswan
# Processing Record [record_count] of Set 1 | borsa
# Processing Record [record_count] of Set 1 | dawlatabad
# Processing Record [record_count] of Set 1 | bluff
# Processing Record [record_count] of Set 1 | bredasdorp
# Processing Record [record_count] of Set 1 | nizhnevartovsk
# Processing Record [record_count] of Set 1 | albany
# Processing Record [record_count] of Set 1 | mataura
# Processing Record [record_count] of Set 1 | gazli
# Processing Record [record_count] of Set 1 | saint-philippe
# Processing Record [record_count] of Set 1 | rikitea
# Processing Record [record_count] of Set 1 | kapaa
# Processing Record [record_count] of Set 1 | tuatapere
# Processing Record [record_count] of Set 1 | ulaangom
# Processing Record [record_count] of Set 1 | touho
# Processing Record [record_count] of Set 1 | punta arenas
# Processing Record [record_count] of Set 1 | eydhafushi
# Processing Record [record_count] of Set 1 | bambous virieux
# Processing Record [record_count] of Set 1 | namatanai
# Processing Record [record_count] of Set 1 | vaini
# Processing Record [record_count] of Set 1 | ushuaia
# Processing Record [record_count] of Set 1 | new norfolk
# Processing Record [record_count] of Set 1 | busselton
# Processing Record [record_count] of Set 1 | fort nelson
# Processing Record [record_count] of Set 1 | sergeyevka
# Processing Record [record_count] of Set 1 | lebu
# Processing Record [record_count] of Set 1 | zunyi
# Processing Record [record_count] of Set 1 | clyde river
# Processing Record [record_count] of Set 1 | bengkulu
# Processing Record [record_count] of Set 1 | grindavik
# Processing Record [record_count] of Set 1 | sinnamary
# Processing Record [record_count] of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record [record_count] of Set 1 | poykovskiy
# Processing Record [record_count] of Set 1 | kununurra
# Processing Record [record_count] of Set 1 | thompson
# Processing Record [record_count] of Set 1 | ilulissat
# Processing Record [record_count] of Set 1 | bethel
# Processing Record [record_count] of Set 1 | jamestown
# Processing Record [record_count] of Set 1 | port alfred
# Processing Record [record_count] of Set 1 | kavaratti
# Processing Record [record_count] of Set 2 | kaitangata
# Processing Record [record_count] of Set 2 | kodiak
# Processing Record [record_count] of Set 2 | vila velha
# Processing Record [record_count] of Set 2 | port elizabeth
# Processing Record [record_count] of Set 2 | castro
# Processing Record [record_count] of Set 2 | skjaerhollen
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | hilo
# Processing Record [record_count] of Set 2 | barsovo
# Processing Record [record_count] of Set 2 | hendrina
# Processing Record [record_count] of Set 2 | kruisfontein
# Processing Record [record_count] of Set 2 | amderma
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | itarema
# Processing Record [record_count] of Set 2 | marathon
# Processing Record [record_count] of Set 2 | fortuna
# Processing Record [record_count] of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | kapoeta
# Processing Record [record_count] of Set 2 | hobart
# Processing Record [record_count] of Set 2 | tevaitoa
# Processing Record [record_count] of Set 2 | lang son
# Processing Record [record_count] of Set 2 | kindu
# Processing Record [record_count] of Set 2 | yellowknife
# Processing Record [record_count] of Set 2 | verin
# Processing Record [record_count] of Set 2 | tambacounda
# Processing Record [record_count] of Set 2 | ambilobe
# Processing Record [record_count] of Set 2 | ancud
# Processing Record [record_count] of Set 2 | saskylakh
# Processing Record [record_count] of Set 2 | belaya gora
# Processing Record [record_count] of Set 2 | barrow
# Processing Record [record_count] of Set 2 | hobyo
# Processing Record [record_count] of Set 2 | iqaluit
# Processing Record [record_count] of Set 2 | yulara
# Processing Record [record_count] of Set 2 | pevek
# Processing Record [record_count] of Set 2 | kirakira
# Processing Record [record_count] of Set 2 | atuona
# Processing Record [record_count] of Set 2 | ormara
# Processing Record [record_count] of Set 2 | tuktoyaktuk
# Processing Record [record_count] of Set 2 | cape town
# Processing Record [record_count] of Set 2 | butaritari
# Processing Record [record_count] of Set 2 | ponta delgada
# Processing Record [record_count] of Set 2 | cherskiy
# Processing Record [record_count] of Set 2 | puerto escondido
# Processing Record [record_count] of Set 2 | rafaela
# Processing Record [record_count] of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record [record_count] of Set 2 | chokurdakh
# Processing Record [record_count] of Set 2 | sao filipe
# Processing Record [record_count] of Set 2 | dekar
# Processing Record [record_count] of Set 2 | yumen
# Processing Record [record_count] of Set 2 | san ignacio
# Processing Record [record_count] of Set 3 | cabo san lucas
# Processing Record [record_count] of Set 3 | mmabatho
# Processing Record [record_count] of Set 3 | komsomolskiy
# Processing Record [record_count] of Set 3 | sinjai
# Processing Record [record_count] of Set 3 | guayaramerin
# Processing Record [record_count] of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record [record_count] of Set 3 | baoshan
# Processing Record [record_count] of Set 3 | ipixuna
# Processing Record [record_count] of Set 3 | moron
# Processing Record [record_count] of Set 3 | longyearbyen
# Processing Record [record_count] of Set 3 | camacha
# Processing Record [record_count] of Set 3 | port moresby
# Processing Record [record_count] of Set 3 | toliary
# City not found. Skipping...
# Processing Record [record_count] of Set 3 | klaksvik
# Processing Record [record_count] of Set 3 | stromness
# Processing Record [record_count] of Set 3 | avarua
# Processing Record [record_count] of Set 3 | coos bay
# Processing Record [record_count] of Set 3 | businga
# Processing Record [record_count] of Set 3 | kibondo
# Processing Record [record_count] of Set 3 | nexo
# Processing Record [record_count] of Set 3 | taft
# Processing Record [record_count] of Set 3 | leningradskiy
# Processing Record [record_count] of Set 3 | te anau
# Processing Record [record_count] of Set 3 | khatanga
# Processing Record [record_count] of Set 3 | saint anthony
# Processing Record [record_count] of Set 3 | port keats
# Processing Record [record_count] of Set 3 | dakar
# Processing Record [record_count] of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record [record_count] of Set 3 | fosforitnyy
# Processing Record [record_count] of Set 3 | perelyub
# Processing Record [record_count] of Set 3 | isangel
# Processing Record [record_count] of Set 3 | severo-kurilsk
# Processing Record [record_count] of Set 3 | hermanus
# Processing Record [record_count] of Set 3 | tasiilaq
# Processing Record [record_count] of Set 3 | shache
# Processing Record [record_count] of Set 3 | alta floresta
# Processing Record [record_count] of Set 3 | flinders
# Processing Record [record_count] of Set 3 | nizhniy tsasuchey
# Processing Record [record_count] of Set 3 | asyut
# Processing Record [record_count] of Set 3 | nampula
# Processing Record [record_count] of Set 3 | sorbhog
# Processing Record [record_count] of Set 3 | chuguyevka
# Processing Record [record_count] of Set 3 | alfenas
# Processing Record [record_count] of Set 3 | sirur
# Processing Record [record_count] of Set 3 | cidreira
# Processing Record [record_count] of Set 3 | touros
# Processing Record [record_count] of Set 3 | shama
# Processing Record [record_count] of Set 3 | pangkalanbuun
# Processing Record [record_count] of Set 3 | bantogon
# Processing Record [record_count] of Set 3 | puerto ayora
# Processing Record [record_count] of Set 4 | kieta
# Processing Record [record_count] of Set 4 | faanui
# Processing Record [record_count] of Set 4 | dunedin
# Processing Record [record_count] of Set 4 | galgani
# City not found. Skipping...
# Processing Record [record_count] of Set 4 | anadyr
# Processing Record [record_count] of Set 4 | hvammstangi
# City not found. Skipping...
# Processing Record [record_count] of Set 4 | pemba
# Processing Record [record_count] of Set 4 | opuwo
# Processing Record [record_count] of Set 4 | pitea
# Processing Record [record_count] of Set 4 | longlac
# City not found. Skipping...
# Processing Record [record_count] of Set 4 | fairbanks
# Processing Record [record_count] of Set 4 | aykhal
# Processing Record [record_count] of Set 4 | skibbereen
# Processing Record [record_count] of Set 4 | luyang
# Processing Record [record_count] of Set 4 | gaurnadi
# Processing Record [record_count] of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record [record_count] of Set 4 | xichang
# Processing Record [record_count] of Set 4 | borba
# Processing Record [record_count] of Set 4 | atamanovka
# Processing Record [record_count] of Set 4 | zelenogorskiy
# Processing Record [record_count] of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record [record_count] of Set 4 | broome
# Processing Record [record_count] of Set 4 | vanimo
# Processing Record [record_count] of Set 4 | areosa
# Processing Record [record_count] of Set 4 | pimentel
# Processing Record [record_count] of Set 4 | magole
# Processing Record [record_count] of Set 4 | dubrovytsya
# Processing Record [record_count] of Set 4 | ayagoz
# Processing Record [record_count] of Set 4 | raudeberg
# Processing Record [record_count] of Set 4 | khandagayty
# Processing Record [record_count] of Set 4 | tual
# Processing Record [record_count] of Set 4 | kimparana
# Processing Record [record_count] of Set 4 | abancay
# Processing Record [record_count] of Set 4 | nueva loja
# Processing Record [record_count] of Set 4 | los llanos de aridane
# Processing Record [record_count] of Set 4 | mount gambier
# Processing Record [record_count] of Set 4 | airai
# Processing Record [record_count] of Set 4 | pringsewu
# Processing Record [record_count] of Set 4 | bandar-e anzali
# Processing Record [record_count] of Set 4 | orneta
# Processing Record [record_count] of Set 4 | berlevag
# Processing Record [record_count] of Set 4 | dovolnoye
# Processing Record [record_count] of Set 4 | honningsvag
# Processing Record [record_count] of Set 4 | oktyabrskoye
# Processing Record [record_count] of Set 4 | mahebourg
# Processing Record [record_count] of Set 4 | sao raimundo das mangabeiras
# Processing Record [record_count] of Set 4 | buraydah
# Processing Record [record_count] of Set 4 | upernavik
# Processing Record [record_count] of Set 4 | aklavik
# Processing Record [record_count] of Set 4 | ilhabela
# Processing Record [record_count] of Set 5 | bonavista
# Processing Record [record_count] of Set 5 | talnakh
# Processing Record [record_count] of Set 5 | cairns
# Processing Record [record_count] of Set 5 | stanghelle
# Processing Record [record_count] of Set 5 | luangwa
# Processing Record [record_count] of Set 5 | xinyu
# Processing Record [record_count] of Set 5 | lubao
# Processing Record [record_count] of Set 5 | buala
# Processing Record [record_count] of Set 5 | mildura
# Processing Record [record_count] of Set 5 | sakakah
# Processing Record [record_count] of Set 5 | balimo
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | chuy
# Processing Record [record_count] of Set 5 | tessalit
# Processing Record [record_count] of Set 5 | amalapuram
# Processing Record [record_count] of Set 5 | lovozero
# Processing Record [record_count] of Set 5 | pervoye maya
# Processing Record [record_count] of Set 5 | tezu
# Processing Record [record_count] of Set 5 | coquimbo
# Processing Record [record_count] of Set 5 | rypefjord
# Processing Record [record_count] of Set 5 | sampit
# Processing Record [record_count] of Set 5 | vestmannaeyjar
# Processing Record [record_count] of Set 5 | norman wells
# Processing Record [record_count] of Set 5 | ballarat
# Processing Record [record_count] of Set 5 | aripuana
# Processing Record [record_count] of Set 5 | qasigiannguit
# Processing Record [record_count] of Set 5 | hopkinsville
# Processing Record [record_count] of Set 5 | niwari
# Processing Record [record_count] of Set 5 | santa rosa
# Processing Record [record_count] of Set 5 | isabela
# Processing Record [record_count] of Set 5 | kargopol
# Processing Record [record_count] of Set 5 | baoqing
# Processing Record [record_count] of Set 5 | namwala
# Processing Record [record_count] of Set 5 | cajamarca
# Processing Record [record_count] of Set 5 | bonwapitse
# Processing Record [record_count] of Set 5 | provideniya
# Processing Record [record_count] of Set 5 | tautira
# Processing Record [record_count] of Set 5 | strezhevoy
# Processing Record [record_count] of Set 5 | bilma
# Processing Record [record_count] of Set 5 | aljezur
# Processing Record [record_count] of Set 5 | lock haven
# Processing Record [record_count] of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record [record_count] of Set 5 | whitecourt
# Processing Record [record_count] of Set 5 | novomalorossiyskaya
# Processing Record [record_count] of Set 5 | atasu
# Processing Record [record_count] of Set 5 | ponta do sol
# Processing Record [record_count] of Set 5 | jega
# Processing Record [record_count] of Set 5 | wasilla
# Processing Record [record_count] of Set 5 | manjacaze
# Processing Record [record_count] of Set 5 | saldanha
# Processing Record [record_count] of Set 5 | puerto madryn
# Processing Record [record_count] of Set 6 | ritchie
# Processing Record [record_count] of Set 6 | qaanaaq
# Processing Record [record_count] of Set 6 | mogadishu
# Processing Record [record_count] of Set 6 | east london
# Processing Record [record_count] of Set 6 | dicabisagan
# Processing Record [record_count] of Set 6 | arraial do cabo
# Processing Record [record_count] of Set 6 | viedma
# Processing Record [record_count] of Set 6 | muros
# Processing Record [record_count] of Set 6 | pisco
# Processing Record [record_count] of Set 6 | shahgarh
# Processing Record [record_count] of Set 6 | mataram
# Processing Record [record_count] of Set 6 | la plata
# Processing Record [record_count] of Set 6 | georgetown
# Processing Record [record_count] of Set 6 | tirukkattuppalli
# City not found. Skipping...
# Processing Record [record_count] of Set 6 | flin flon
# Processing Record [record_count] of Set 6 | arica
# Processing Record [record_count] of Set 6 | port blair
# Processing Record [record_count] of Set 6 | abu kamal
# Processing Record [record_count] of Set 6 | kangaba
# Processing Record [record_count] of Set 6 | henties bay
# Processing Record [record_count] of Set 6 | lavrentiya
# Processing Record [record_count] of Set 6 | bargal
# City not found. Skipping...
# Processing Record [record_count] of Set 6 | sao felix do xingu
# Processing Record [record_count] of Set 6 | salalah
# Processing Record [record_count] of Set 6 | waipawa
# Processing Record [record_count] of Set 6 | kavieng
# Processing Record [record_count] of Set 6 | praia da vitoria
# Processing Record [record_count] of Set 6 | bathsheba
# Processing Record [record_count] of Set 6 | kahului
# Processing Record [record_count] of Set 6 | fayaoue
# Processing Record [record_count] of Set 6 | novikovo
# Processing Record [record_count] of Set 6 | nioro
# Processing Record [record_count] of Set 6 | jacareacanga
# Processing Record [record_count] of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record [record_count] of Set 6 | conakry
# Processing Record [record_count] of Set 6 | husavik
# Processing Record [record_count] of Set 6 | taguatinga
# Processing Record [record_count] of Set 6 | kenai
# Processing Record [record_count] of Set 6 | alyangula
# Processing Record [record_count] of Set 6 | cabo rojo
# Processing Record [record_count] of Set 6 | tete
# Processing Record [record_count] of Set 6 | baft
# Processing Record [record_count] of Set 6 | ribeira grande
# Processing Record [record_count] of Set 6 | shagonar
# Processing Record [record_count] of Set 6 | vitim
# Processing Record [record_count] of Set 6 | araouane
# Processing Record [record_count] of Set 6 | westport
# Processing Record [record_count] of Set 6 | coihaique
# Processing Record [record_count] of Set 6 | bismarck
# Processing Record [record_count] of Set 6 | coroico
# Processing Record [record_count] of Set 7 | mastic beach
# Processing Record [record_count] of Set 7 | cururupu
# Processing Record [record_count] of Set 7 | leh
# Processing Record [record_count] of Set 7 | caravelas
# Processing Record [record_count] of Set 7 | straumen
# Processing Record [record_count] of Set 7 | luderitz
# Processing Record [record_count] of Set 7 | ahuimanu
# Processing Record [record_count] of Set 7 | abalak
# Processing Record [record_count] of Set 7 | ambulu
# Processing Record [record_count] of Set 7 | baykit
# Processing Record [record_count] of Set 7 | katangli
# Processing Record [record_count] of Set 7 | xiaoshi
# Processing Record [record_count] of Set 7 | saint george
# Processing Record [record_count] of Set 7 | porto novo
# Processing Record [record_count] of Set 7 | maningrida
# Processing Record [record_count] of Set 7 | hasaki
# Processing Record [record_count] of Set 7 | kutahya
# Processing Record [record_count] of Set 7 | guerrero negro
# Processing Record [record_count] of Set 7 | hambantota
# Processing Record [record_count] of Set 7 | fereydun kenar
# Processing Record [record_count] of Set 7 | marion
# Processing Record [record_count] of Set 7 | la libertad
# Processing Record [record_count] of Set 7 | luanda
# Processing Record [record_count] of Set 7 | beloha
# Processing Record [record_count] of Set 7 | nanortalik
# Processing Record [record_count] of Set 7 | mana
# Processing Record [record_count] of Set 7 | carolina
# Processing Record [record_count] of Set 7 | huangnihe
# Processing Record [record_count] of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | esperance
# Processing Record [record_count] of Set 7 | isla mujeres
# Processing Record [record_count] of Set 7 | saint pete beach
# Processing Record [record_count] of Set 7 | athabasca
# Processing Record [record_count] of Set 7 | kilindoni
# Processing Record [record_count] of Set 7 | cap malheureux
# Processing Record [record_count] of Set 7 | dingle
# Processing Record [record_count] of Set 7 | karamay
# City not found. Skipping...
# Processing Record [record_count] of Set 7 | berdigestyakh
# Processing Record [record_count] of Set 7 | prince george
# Processing Record [record_count] of Set 7 | boshnyakovo
# Processing Record [record_count] of Set 7 | klichka
# Processing Record [record_count] of Set 7 | tahe
# Processing Record [record_count] of Set 7 | port lincoln
# Processing Record [record_count] of Set 7 | mandalgovi
# Processing Record [record_count] of Set 7 | hamilton
# Processing Record [record_count] of Set 7 | san matias
# Processing Record [record_count] of Set 7 | ahipara
# Processing Record [record_count] of Set 7 | umred
# Processing Record [record_count] of Set 7 | pierre
# Processing Record [record_count] of Set 7 | lagos
# Processing Record [record_count] of Set 8 | pilar
# Processing Record [record_count] of Set 8 | pandan
# Processing Record [record_count] of Set 8 | padang
# Processing Record [record_count] of Set 8 | baruun-urt
# Processing Record [record_count] of Set 8 | wajid
# Processing Record [record_count] of Set 8 | sitka
# Processing Record [record_count] of Set 8 | baghdad
# Processing Record [record_count] of Set 8 | beypur
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | vardo
# Processing Record [record_count] of Set 8 | jaipur hat
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | manzil jamil
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | hami
# Processing Record [record_count] of Set 8 | nhamunda
# Processing Record [record_count] of Set 8 | itoman
# Processing Record [record_count] of Set 8 | borogontsy
# Processing Record [record_count] of Set 8 | nizhniy baskunchak
# Processing Record [record_count] of Set 8 | nouadhibou
# Processing Record [record_count] of Set 8 | moranbah
# Processing Record [record_count] of Set 8 | ituango
# Processing Record [record_count] of Set 8 | walvis bay
# Processing Record [record_count] of Set 8 | menongue
# Processing Record [record_count] of Set 8 | havelock
# Processing Record [record_count] of Set 8 | takoradi
# Processing Record [record_count] of Set 8 | karangasem
# Processing Record [record_count] of Set 8 | ambon
# Processing Record [record_count] of Set 8 | korla
# Processing Record [record_count] of Set 8 | general roca
# Processing Record [record_count] of Set 8 | tocopilla
# Processing Record [record_count] of Set 8 | milkovo
# Processing Record [record_count] of Set 8 | melfi
# Processing Record [record_count] of Set 8 | tiksi
# Processing Record [record_count] of Set 8 | centenario do sul
# Processing Record [record_count] of Set 8 | eyl
# Processing Record [record_count] of Set 8 | narsaq
# Processing Record [record_count] of Set 8 | dhidhdhoo
# Processing Record [record_count] of Set 8 | lagoa
# Processing Record [record_count] of Set 8 | richards bay
# Processing Record [record_count] of Set 8 | sao paulo de olivenca
# Processing Record [record_count] of Set 8 | labuhan
# Processing Record [record_count] of Set 8 | zyryanka
# Processing Record [record_count] of Set 8 | portland
# Processing Record [record_count] of Set 8 | dabwali
# Processing Record [record_count] of Set 8 | sorvag
# City not found. Skipping...
# Processing Record [record_count] of Set 8 | mbandaka
# Processing Record [record_count] of Set 8 | amurzet
# Processing Record [record_count] of Set 8 | awjilah
# Processing Record [record_count] of Set 8 | saint-joseph
# Processing Record [record_count] of Set 8 | saurimo
# Processing Record [record_count] of Set 8 | juneau
# Processing Record [record_count] of Set 8 | hihifo
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | katsuura
# Processing Record [record_count] of Set 9 | noumea
# Processing Record [record_count] of Set 9 | saint-louis
# Processing Record [record_count] of Set 9 | zatoka
# Processing Record [record_count] of Set 9 | buique
# Processing Record [record_count] of Set 9 | vostok
# Processing Record [record_count] of Set 9 | sao mateus do sul
# Processing Record [record_count] of Set 9 | balikpapan
# Processing Record [record_count] of Set 9 | hovd
# Processing Record [record_count] of Set 9 | geraldton
# Processing Record [record_count] of Set 9 | huilong
# Processing Record [record_count] of Set 9 | tucuma
# Processing Record [record_count] of Set 9 | moyale
# Processing Record [record_count] of Set 9 | sultanpur
# Processing Record [record_count] of Set 9 | yeletskiy
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | mehamn
# Processing Record [record_count] of Set 9 | pihuamo
# Processing Record [record_count] of Set 9 | jacqueville
# Processing Record [record_count] of Set 9 | balabac
# Processing Record [record_count] of Set 9 | morehead
# Processing Record [record_count] of Set 9 | nuuk
# Processing Record [record_count] of Set 9 | chumikan
# Processing Record [record_count] of Set 9 | constitucion
# Processing Record [record_count] of Set 9 | parrita
# Processing Record [record_count] of Set 9 | virginia beach
# Processing Record [record_count] of Set 9 | conceicao do araguaia
# Processing Record [record_count] of Set 9 | marcona
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | korneuburg
# Processing Record [record_count] of Set 9 | valera
# Processing Record [record_count] of Set 9 | muhammadabad
# Processing Record [record_count] of Set 9 | hithadhoo
# Processing Record [record_count] of Set 9 | illapel
# Processing Record [record_count] of Set 9 | sur
# Processing Record [record_count] of Set 9 | oneida
# Processing Record [record_count] of Set 9 | naze
# Processing Record [record_count] of Set 9 | vila franca do campo
# Processing Record [record_count] of Set 9 | comodoro rivadavia
# Processing Record [record_count] of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | barawe
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | port augusta
# Processing Record [record_count] of Set 9 | quang ngai
# Processing Record [record_count] of Set 9 | galle
# Processing Record [record_count] of Set 9 | karratha
# Processing Record [record_count] of Set 9 | adrar
# Processing Record [record_count] of Set 9 | caconda
# Processing Record [record_count] of Set 9 | kostomuksha
# Processing Record [record_count] of Set 9 | antofagasta
# Processing Record [record_count] of Set 9 | gurgan
# City not found. Skipping...
# Processing Record [record_count] of Set 9 | maniwaki
# Processing Record [record_count] of Set 9 | esso
# Processing Record [record_count] of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | yei
# Processing Record [record_count] of Set 10 | matay
# Processing Record [record_count] of Set 10 | trincomalee
# Processing Record [record_count] of Set 10 | batagay-alyta
# Processing Record [record_count] of Set 10 | gigmoto
# Processing Record [record_count] of Set 10 | san felipe
# Processing Record [record_count] of Set 10 | lorengau
# Processing Record [record_count] of Set 10 | laredo
# Processing Record [record_count] of Set 10 | verkhnyaya inta
# Processing Record [record_count] of Set 10 | saint marys
# Processing Record [record_count] of Set 10 | weiden
# Processing Record [record_count] of Set 10 | sarankhola
# Processing Record [record_count] of Set 10 | agfalva
# Processing Record [record_count] of Set 10 | angoche
# Processing Record [record_count] of Set 10 | shamgarh
# Processing Record [record_count] of Set 10 | filadelfia
# Processing Record [record_count] of Set 10 | lumsden
# Processing Record [record_count] of Set 10 | bandarbeyla
# Processing Record [record_count] of Set 10 | jijiang
# Processing Record [record_count] of Set 10 | haines junction
# Processing Record [record_count] of Set 10 | madison heights
# Processing Record [record_count] of Set 10 | torbay
# Processing Record [record_count] of Set 10 | asti
# Processing Record [record_count] of Set 10 | nabire
# Processing Record [record_count] of Set 10 | orapa
# Processing Record [record_count] of Set 10 | mahibadhoo
# Processing Record [record_count] of Set 10 | meulaboh
# Processing Record [record_count] of Set 10 | souillac
# Processing Record [record_count] of Set 10 | umm durman
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | myrtle beach
# Processing Record [record_count] of Set 10 | monrovia
# Processing Record [record_count] of Set 10 | mlonggo
# Processing Record [record_count] of Set 10 | roswell
# Processing Record [record_count] of Set 10 | nalut
# Processing Record [record_count] of Set 10 | luena
# Processing Record [record_count] of Set 10 | shchelyayur
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | rehoboth
# Processing Record [record_count] of Set 10 | niquero
# Processing Record [record_count] of Set 10 | kuche
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | trelew
# Processing Record [record_count] of Set 10 | daru
# Processing Record [record_count] of Set 10 | dukat
# Processing Record [record_count] of Set 10 | okakarara
# Processing Record [record_count] of Set 10 | viljoenskroon
# Processing Record [record_count] of Set 10 | chapada dos guimaraes
# Processing Record [record_count] of Set 10 | kalomo
# City not found. Skipping...
# Processing Record [record_count] of Set 10 | alofi
# Processing Record [record_count] of Set 10 | fallon
# Processing Record [record_count] of Set 10 | ostrow wielkopolski
# Processing Record [record_count] of Set 11 | igurubi
# Processing Record [record_count] of Set 11 | gulshat
# City not found. Skipping...
# Processing Record [record_count] of Set 11 | trairi
# Processing Record [record_count] of Set 11 | banjar
# Processing Record [record_count] of Set 11 | baturaja
# Processing Record [record_count] of Set 11 | ishigaki
# Processing Record [record_count] of Set 11 | ostersund
# Processing Record [record_count] of Set 11 | shirpur
# Processing Record [record_count] of Set 11 | kiunga
# Processing Record [record_count] of Set 11 | bagnes
# Processing Record [record_count] of Set 11 | faya
# Processing Record [record_count] of Set 11 | chengde
# Processing Record [record_count] of Set 11 | kulhudhuffushi
# Processing Record [record_count] of Set 11 | lakes entrance
# Processing Record [record_count] of Set 11 | sungaipenuh
# Processing Record [record_count] of Set 11 | guanare
# Processing Record [record_count] of Set 11 | goderich
# Processing Record [record_count] of Set 11 | necochea
# Processing Record [record_count] of Set 11 | saint-augustin
# Processing Record [record_count] of Set 11 | labuan
# Processing Record [record_count] of Set 11 | san patricio
# Processing Record [record_count] of Set 11 | kutum
# Processing Record [record_count] of Set 11 | broken hill
# Processing Record [record_count] of Set 11 | tutoia
# Processing Record [record_count] of Set 11 | safwah
# City not found. Skipping...
# Processing Record [record_count] of Set 11 | sorland
# Processing Record [record_count] of Set 11 | yerbogachen
# Processing Record [record_count] of Set 11 | ilembula
# Processing Record [record_count] of Set 11 | mizdah
# Processing Record [record_count] of Set 11 | laguna
# Processing Record [record_count] of Set 11 | innisfail
# Processing Record [record_count] of Set 11 | rodrigues alves
# Processing Record [record_count] of Set 11 | estreito
# Processing Record [record_count] of Set 11 | hearst
# Processing Record [record_count] of Set 11 | half moon bay
# Processing Record [record_count] of Set 11 | dinguiraye
# Processing Record [record_count] of Set 11 | hay river
# Processing Record [record_count] of Set 11 | ingham
# Processing Record [record_count] of Set 11 | port hardy
# Processing Record [record_count] of Set 11 | ochamchira
# Processing Record [record_count] of Set 11 | bubaque
# Processing Record [record_count] of Set 11 | teya
# Processing Record [record_count] of Set 11 | mackay
# Processing Record [record_count] of Set 11 | dryden
# Processing Record [record_count] of Set 11 | lima
# Processing Record [record_count] of Set 11 | the valley
# Processing Record [record_count] of Set 11 | altay
# Processing Record [record_count] of Set 11 | beringovskiy
# Processing Record [record_count] of Set 11 | george town
# Processing Record [record_count] of Set 11 | usinsk
# Processing Record [record_count] of Set 12 | nea fokaia
# Processing Record [record_count] of Set 12 | tigil
# Processing Record [record_count] of Set 12 | paamiut
# Processing Record [record_count] of Set 12 | saint-leu
# Processing Record [record_count] of Set 12 | ballina
# Processing Record [record_count] of Set 12 | canico
# Processing Record [record_count] of Set 12 | labutta
# City not found. Skipping...
# Processing Record [record_count] of Set 12 | karoi
# Processing Record [record_count] of Set 12 | ordu
# Processing Record [record_count] of Set 12 | talcahuano
# Processing Record [record_count] of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record [record_count] of Set 12 | san cristobal
# Processing Record [record_count] of Set 12 | kilakarai
# Processing Record [record_count] of Set 12 | tikrit
# Processing Record [record_count] of Set 12 | victor harbor
# Processing Record [record_count] of Set 12 | plover
# Processing Record [record_count] of Set 12 | sena madureira
# Processing Record [record_count] of Set 12 | tilichiki
# Processing Record [record_count] of Set 12 | quatre cocos
# Processing Record [record_count] of Set 12 | berikulskiy
# City not found. Skipping...
# Processing Record [record_count] of Set 12 | petropavlovsk-kamchatskiy
# Processing Record [record_count] of Set 12 | samusu
# City not found. Skipping...
# Processing Record [record_count] of Set 12 | nassjo
# Processing Record [record_count] of Set 12 | vila
# Processing Record [record_count] of Set 12 | alice springs
# Processing Record [record_count] of Set 12 | porosozero
# Processing Record [record_count] of Set 12 | biltine
# Processing Record [record_count] of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record [record_count] of Set 12 | utiroa
# City not found. Skipping...
# Processing Record [record_count] of Set 12 | margate
# Processing Record [record_count] of Set 12 | ust-tsilma
# Processing Record [record_count] of Set 12 | tiznit
# Processing Record [record_count] of Set 12 | stara vyzhivka
# Processing Record [record_count] of Set 12 | solotcha
# Processing Record [record_count] of Set 12 | mayo
# Processing Record [record_count] of Set 12 | honiara
# Processing Record [record_count] of Set 12 | penzance
# Processing Record [record_count] of Set 12 | kysyl-syr
# Processing Record [record_count] of Set 12 | nhulunbuy
# Processing Record [record_count] of Set 12 | huarmey
# Processing Record [record_count] of Set 12 | aracati
# Processing Record [record_count] of Set 12 | gorin
# Processing Record [record_count] of Set 12 | creston
# Processing Record [record_count] of Set 12 | oni
# Processing Record [record_count] of Set 12 | alappuzha
# Processing Record [record_count] of Set 12 | caraz
# Processing Record [record_count] of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record [record_count] of Set 12 | jorhat
# Processing Record [record_count] of Set 12 | bartica
# Processing Record [record_count] of Set 12 | balkhash
# Processing Record [record_count] of Set 13 | beidao
# Processing Record [record_count] of Set 13 | alexandria
# Processing Record [record_count] of Set 13 | francistown
# Processing Record [record_count] of Set 13 | yakovlevka
# Processing Record [record_count] of Set 13 | howard springs
# Processing Record [record_count] of Set 13 | tono
# Processing Record [record_count] of Set 13 | sept-iles
# Processing Record [record_count] of Set 13 | ous
# Processing Record [record_count] of Set 13 | kirkwall
# Processing Record [record_count] of Set 13 | muroto
# Processing Record [record_count] of Set 13 | marystown
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Carnarvon -24.8667  113.6333     70.68        71           0
# 1      Gazalkent  41.5581   69.7708     80.02        29           0
# 2    Pangnirtung  66.1451  -65.7125     45.97        85          84
# 3    Deputatskiy  69.3000  139.9000     51.62        66         100
# 4         Dikson  73.5069   80.5464     44.55        70          99
# 5     Nikolskoye  59.7035   30.7861     62.80        85          34
# 6         Lompoc  34.6391 -120.4579     78.01        76           0
# 7  Mar Del Plata -38.0023  -57.5575     50.09        82           0
# 8        Taksimo  56.3444  114.8794     72.57        54          47
# 9          Aswan  24.0934   32.9070     85.30        20           0
#
#    Wind Speed Country                 Date
# 0       10.69      AU  2022-07-14 01:37:49
# 1        6.44      UZ  2022-07-14 01:37:50
# 2        2.71      CA  2022-07-14 01:35:46
# 3        6.51      RU  2022-07-14 01:33:19
# 4        5.21      RU  2022-07-14 01:37:50
# 5        4.97      RU  2022-07-14 01:37:50
# 6       13.80      US  2022-07-14 01:37:51
# 7       14.00      AR  2022-07-14 01:37:51
# 8        3.40      RU  2022-07-14 01:37:51
# 9        5.75      EG  2022-07-14 01:37:52

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
new_city_df = city_data_df[new_column_order]
new_city_df.head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0    Carnarvon      AU  2022-07-14 01:37:49 -24.8667  113.6333     70.68
# 1    Gazalkent      UZ  2022-07-14 01:37:50  41.5581   69.7708     80.02
# 2  Pangnirtung      CA  2022-07-14 01:35:46  66.1451  -65.7125     45.97
# 3  Deputatskiy      RU  2022-07-14 01:33:19  69.3000  139.9000     51.62
# 4       Dikson      RU  2022-07-14 01:37:50  73.5069   80.5464     44.55
#
#    Humidity  Cloudiness  Wind Speed
# 0        71           0       10.69
# 1        29           0        6.44
# 2        85          84        2.71
# 3        66         100        6.51
# 4        70          99        5.21

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                   Bredasdorp
# Lat                      -34.5322
# Lng                       20.0403
# Max Temp                     58.1
# Humidity                       79
# Cloudiness                     76
# Wind Speed                  16.24
# Country                        ZA
# Date          2022-07-14 01:37:53
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 559     True
# 560     True
# 561     True
# 562     True
# 563     True
# Name: Lat, Length: 564, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 1    Gazalkent  41.5581   69.7708     80.02        29           0        6.44
# 2  Pangnirtung  66.1451  -65.7125     45.97        85          84        2.71
# 3  Deputatskiy  69.3000  139.9000     51.62        66         100        6.51
# 4       Dikson  73.5069   80.5464     44.55        70          99        5.21
# 5   Nikolskoye  59.7035   30.7861     62.80        85          34        4.97
#
#   Country                 Date
# 1      UZ  2022-07-14 01:37:50
# 2      CA  2022-07-14 01:35:46
# 3      RU  2022-07-14 01:33:19
# 4      RU  2022-07-14 01:37:50
# 5      RU  2022-07-14 01:37:50

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-45,85))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,30))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-40,25))
